# %%
#https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html

# %matplotlib inline
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from scipy.interpolate import interp2d
from scipy.interpolate import LinearNDInterpolator as linND

import matplotlib as mpl 
mpl.rcParams['figure.figsize'] = [12.0, 8.0]
mpl.rcParams.update({'font.size': 20})
mpl.rcParams.update({'figure.facecolor': 'white'})

# %% [markdown]
# ### 1-D interpolation

# %%
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.cos(-x**2/9.0)
plt.plot(x,y, 'o-')

# %%
# this creates a function-like "call method"
f = interp1d(x, y)
f2 = interp1d(x,y, kind = 'cubic')

# kind : str or int, optional
#  |      Specifies the kind of interpolation as a string
#  |      ('linear', 'nearest', 'zero', 'slinear', 'quadratic, 'cubic'
#  |      where 'slinear', 'quadratic' and 'cubic' refer to a spline
#  |      interpolation of first, second or third order) or as an integer
#  |      specifying the order of the spline interpolator to use.
#  |      Default is 'linear'

# %%
# create a new basis vector and interpolate to it
xnew = np.linspace(0, 10, num=41, endpoint=True)
plt.plot(x, y, 'o', xnew, f(xnew), '.-', xnew, f2(xnew), '--x')
plt.legend(['data', 'linear', 'cubic'], loc='best')

# %% [markdown]
# ### Multivariate data interpolation: unstructured data

# %% [markdown]
# Note this only works 1-D inputs, i.e. z is 1-D array

# %%
def func(x, y):
    return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2

# %%
# want 2D data on this grid
grid_x, grid_y = np.mgrid[0:1:100j, 0:1:200j]

# %%
grid_x.shape
# Out:
# (100, 200)

# %%
# but we only have data on this grid (note that values is a 1-D array)
points = np.random.rand(1000, 2)
values = func(points[:,0], points[:,1])

# %%
print values.shape, points.shape
# Out:
# (1000,) (1000, 2)

# %%
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')
grid_z1 = griddata(points, values, (grid_x, grid_y), method='linear')
grid_z2 = griddata(points, values, (grid_x, grid_y), method='cubic')

# %%
# note this also works:
grid_z0T = griddata((points[:,0], points[:,1]), values, (grid_x, grid_y), method='nearest')

# %%
plt.subplot(221)
plt.pcolormesh(grid_x,grid_y,grid_z0, vmax = 0.25, vmin = -0.25)
plt.colorbar()

plt.subplot(222)
plt.pcolormesh(grid_x,grid_y,grid_z1, vmax = 0.25, vmin = -0.25)
plt.colorbar()

plt.subplot(223)
plt.pcolormesh(grid_x,grid_y,grid_z2, vmax = 0.25, vmin = -0.25)
plt.colorbar()

plt.subplot(224)
plt.pcolormesh(grid_x,grid_y,func(grid_x,grid_y), vmax = 0.25, vmin = -0.25)
plt.colorbar()

# note nans at edges for linear and cubic methods
# Out:
# /glade/apps/opt/matplotlib/1.5.1/gnu-westmere/4.8.5/lib/python2.7/site-packages/matplotlib-1.5.1-py2.7-linux-x86_64.egg/matplotlib/colors.py:581: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)

# %%
griddata?
# also works for 1D

# %% [markdown]
# ### Does this also work for 3D data?

# %%
def func3(x, y, z):
    return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2 + z**2

# %%
# want 2D data on this grid
grid_x, grid_y,grid_z = np.mgrid[0:1:100j, 0:1:200j, 0:1:100j]

# %%
grid_x.shape
# Out:
# (100, 200, 100)

# %%
# but we only have data on this grid (note that values is a 1-D array)

# this makes points between zero and 1:
points = np.random.rand(10000, 3)
values = func3(points[:,0], points[:,1],points[:,2])

# %%
grid_z0 = griddata(points, values, (grid_x, grid_y, grid_z), method='nearest')
grid_z1 = griddata(points, values, (grid_x, grid_y, grid_z), method='linear')

# cubic does not work for 3D data
#grid_z2 = griddata(points, values, (grid_x, grid_y, grid_z), method='cubic')

# %%
grid_z0T = griddata((points[:,0], points[:,1],points[:,2]), values, (grid_x, grid_y, grid_z), method='linear')

# %%
grid_z1.max()
# Out:
# nan

# %%
test = linND(points, values, (grid_x, grid_y, grid_z))
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-37-bbd349891a08> in <module>()
# ----> 1 test = linND(points, values, (grid_x, grid_y, grid_z))
#
# scipy/interpolate/interpnd.pyx in scipy.interpolate.interpnd.LinearNDInterpolator.__init__ (scipy/interpolate/interpnd.c:4934)()
#
# scipy/interpolate/interpnd.pyx in scipy.interpolate.interpnd.NDInterpolatorBase.__init__ (scipy/interpolate/interpnd.c:2851)()
#
# TypeError: float() argument must be a string or a number

# %%
level = 0

plt.subplot(221)
plt.pcolormesh(grid_x[:,:,0],grid_y[:,:,0],grid_z0[:,:,level], vmax = 0.25, vmin = -0.25)
plt.colorbar()


plt.subplot(222)
plt.pcolormesh(grid_x[:,:,0],grid_y[:,:,0],grid_z1[:,:,level], vmax = 0.25, vmin = -0.25)
plt.colorbar()

plt.subplot(223)
plt.pcolormesh(grid_x[:,:,0],grid_y[:,:,0],grid_z0T[:,:,level], vmax = 0.25, vmin = -0.25)
plt.colorbar()


# note not working for linear

# %% [markdown]
# ### 2-D interpolation with arrays

# %% [markdown]
# let's take the gridded example from the last exercise and interpolate to a point not on the grid_x,grid_y grid

# %%
# this works in a similar way to interp1d, as it creates a function
f = interp2d(grid_x, grid_y, func(grid_x,grid_y), kind = 'cubic')

# %%
f(0.41, 0.81)

# %% [markdown]
# very slow (had to restart kernel), not realistic to do in this case

# %% [markdown]
# Try again with passing 1D arrays for grid

# %%
f = interp2d(grid_x[:,0], grid_y[0,:], func(grid_x,grid_y), kind = 'cubic')

# %% [markdown]
# Looks like there is a transposing issue

# %%
test = grid_x[:,0]
print test.shape
test2 = grid_y[0,:]
print test2.shape
print func(grid_x,grid_y).shape
# Out:
# (100,)
# (200,)
# (100, 200)

# %% [markdown]
# Try again with y first in the function call

# %%
f = interp2d(grid_y[0,:], grid_x[:,0], func(grid_x,grid_y), kind = 'cubic')

# %%
f(0.81,0.41)
# Out:
# array([ 0.08804951])

# %%
func(0.41,0.81)
# Out:
# 0.088049614764835263

# %% [markdown]
# Note that the x,y have to be transposed between the two function calls

# %%
# make a new grid to interpolate to
# want 2D data on this grid
grid_x2, grid_y2 = np.mgrid[0:2:100j, 0:2:200j]

# %%
z_2 = f(grid_y2,grid_x2)
print z_2[0].shape
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-27-b780cdf121cb> in <module>()
# ----> 1 z_2 = f(grid_y2,grid_x2)
#       2 print z_2[0].shape
#
# /glade/apps/opt/scipy/0.15.1/intel-autodispatch/14.0.2/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in __call__(self, x, y, dx, dy, assume_sorted)
#     274
#     275         if x.ndim != 1 or y.ndim != 1:
# --> 276             raise ValueError("x and y should both be 1-D arrays")
#     277
#     278         if not assume_sorted:
#
# ValueError: x and y should both be 1-D arrays

# %% [markdown]
# Looks like interp2 function will not take arrays as input

# %%
plt.pcolormesh(grid_x2,grid_y2,z_2 vmax = 0.25, vmin = -0.25)
plt.colorbar()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-18-e2dc1e65b1d3> in <module>()
# ----> 1 plt.pcolormesh(grid_x,grid_y,f(grid_y,grid_x), vmax = 0.25, vmin = -0.25)
#       2 plt.colorbar()
#
# /glade/apps/opt/scipy/0.15.1/intel-autodispatch/14.0.2/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in __call__(self, x, y, dx, dy, assume_sorted)
#     274
#     275         if x.ndim != 1 or y.ndim != 1:
# --> 276             raise ValueError("x and y should both be 1-D arrays")
#     277
#     278         if not assume_sorted:
#
# ValueError: x and y should both be 1-D arrays

# %% [markdown]
# ### 2-D interpolation for regularly gridded arrays

# %% [markdown]
# This can be done for a gridded array, even if uneven spacing.
# Let's try the last example again

# %%
from scipy.interpolate import RegularGridInterpolator

# %%
RegularGridInterpolator?
#RegularGridInterpolator(self, points, values, method='linear', 
#   bounds_error=True, fill_value=nan)

# %% [markdown]
# Note that points need to be 1-D arrays, i.e. vectors

# %%
frg = RegularGridInterpolator(points =[grid_x[:,0], grid_y[0,:]], values = func(grid_x,grid_y))

# %%
frg([0.41,0.81])
# Out:
# array([ 0.08779936])

# %%
func(0.41,0.81)
# Out:
# 0.088049614764835263

# %% [markdown]
# Only options are linear and nearest, this is as good as it gets

# %% [markdown]
# ### Spline 2-D interpolation for regularly gridded arrays

# %%
from scipy.interpolate import RectBivariateSpline
RBS = RectBivariateSpline

# %%
frb = RBS(grid_x[:,0], grid_y[0,:], func(grid_x,grid_y))

# %%
# note difference in syntax from above
frb(0.41,0.81)
# Out:
# array([[ 0.08804951]])

# %% [markdown]
# This gives an answer much closer to the analytical result

# %% [markdown]
# It is akward that these different methods have different ways of calling the created function. Freeware
