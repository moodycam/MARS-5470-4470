# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
# Generates an array with 256 values between -pi and pi
#C is the cosine and S is the sine

# %%
plt.plot(X, C)
plt.plot(X, S)
plt.show()

# %%
# You can change a bunch of stuff
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(X, C, color='blue', linewidth=2.5, linestyle="-")
plt.plot(X, S, color='red', linewidth=2.5, linestyle='-')
# You can change line width, color, and line style

# %% [markdown]
# # All the different modifications to plots that can be done

# %%
# You can also set limits on axis
plt.figure(figsize=(10, 6), dpi=80)
plt.plot(X, C, color='blue', linewidth=2.5, linestyle="-") # Customization
plt.plot(X, S, color='red', linewidth=2.5, linestyle='-') # Customization
plt.xlim(X.min() * 1.1, X.max() * 1.1) # Sets limits
plt.ylim(C.min() * 1.1, C.max() * 1.1) # Sets limits

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi]) # Sets ticks
plt.yticks([-1, 0, +1]) # Sets ticks
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']) #tick labels
plt.yticks([-1, 0, +1],
          [r'$-1$', r'$0$', r'$+1$']) # tick labels

ax = plt.gca()  # gca stands for 'get current axis' 
#Can rearrange stems to make cool plots
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#This is the way for modifying labels
plt.plot(X, C, color='blue', linewidth=2.5, linestyle='-', label='cosine') #Make a legend with axis labels
plt.plot(X, S, color='red', linewidth=2.5, linestyle='-', label='sine')

# This is the way to add cool graphics, equations, or words to a plot
t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

#For elements that intersect each other make it transparent
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65))
   
plt.legend()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Figures, Subplots, Axes and Ticks

# %%
# Some common figure parameters
# num = number of figure
# figsize = figure size in incehs(width, height)
# dpi = resolution in dots per inch
# facecolor = color of drawing background
# edgecolor = color of edge around the drawing background
# frameon = draw figure frame or not

# %%
# Axes allow for placement of plots at any location in the figure

# %%
# You can control the position of ticks
# ax = plt.gca()
# ax.xaxis.set_major_locator(eval(locator))

# %%
# There is different kinds of plots....scatter, bar, contour, imshow, quiver, pie, grid, subplots

# %%
### Examples

# %%
n = 256
x = np.linspace(-np.pi, np.pi, n, endpoint = True)
y = np.sin(2*x)

plt.plot(x, y+1, color='blue', alpha=1.00)
plt.plot(x, y-1, color='blue', alpha=1.00)
