# %% [markdown]
# ## Challenge: in a new notebook use the netcdf file we worked with to make a 4 column 3 row plot of subplots of the SST variable, one for each month. Label each subplot with the month. Include a colorban with "extended" ends, and modify the min and max of the colorban

# %% [markdown]
# ## First step is to import the correct modules for plotting

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import xarray as xr

# %% [markdown]
# ## Then we need to get the netcdf file

# %%
data = xr.open_dataset('/Users/abigailpozulp/Downloads/CESM.003.SST.1980.nc')

lat = np.array(data.lat)
lon = np.array(data.lon)
data = np.array(data.SST)

# %%
data.shape
# the dimensions are 12 months x 180 latitude x 360 longitude
# Out:
# (12, 180, 360)

# %% [markdown]
# ### To Plot the whole data

# %%
fig, ax = plt.subplots()
p = ax.pcolormesh(lon, lat, meandata)
cb = plt.colorbar(p, extend="both")

# %% [markdown]
# ## To Plot a single month

# %%
plt.pcolormesh(data[5,:,:])

# %% [markdown]
# ### To get an array of plots

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, ncols=4, sharex=True, sharey=True)

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, ncols=4, sharex=True, sharey=True)
im = ax[0,0].pcolormesh(lon,lat,data[0,:,:])

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, ncols=4, sharex=True, sharey=True)
im = ax[0,0].pcolormesh(lon,lat,data[0,:,:])
im = ax[0,1].pcolormesh(lon,lat,data[1,:,:])
im = ax[0,2].pcolormesh(lon,lat,data[2,:,:])
im = ax[0,3].pcolormesh(lon,lat,data[3,:,:])
im = ax[1,0].pcolormesh(lon,lat,data[4,:,:])
im = ax[1,1].pcolormesh(lon,lat,data[5,:,:])
im = ax[1,2].pcolormesh(lon,lat,data[6,:,:])
im = ax[1,3].pcolormesh(lon,lat,data[7,:,:])
im = ax[2,0].pcolormesh(lon,lat,data[8,:,:])
im = ax[2,1].pcolormesh(lon,lat,data[9,:,:])
im = ax[2,2].pcolormesh(lon,lat,data[10,:,:])
im = ax[2,3].pcolormesh(lon,lat,data[11,:,:])

# %% [markdown]
# ### include the colorbar

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, ncols=4, sharex=True, sharey=True)
im = ax[0,0].pcolormesh(lon,lat,data[0,:,:])
im = ax[0,1].pcolormesh(lon,lat,data[1,:,:])
im = ax[0,2].pcolormesh(lon,lat,data[2,:,:])
im = ax[0,3].pcolormesh(lon,lat,data[3,:,:])
im = ax[1,0].pcolormesh(lon,lat,data[4,:,:])
im = ax[1,1].pcolormesh(lon,lat,data[5,:,:])
im = ax[1,2].pcolormesh(lon,lat,data[6,:,:])
im = ax[1,3].pcolormesh(lon,lat,data[7,:,:])
im = ax[2,0].pcolormesh(lon,lat,data[8,:,:])
im = ax[2,1].pcolormesh(lon,lat,data[9,:,:])
im = ax[2,2].pcolormesh(lon,lat,data[10,:,:])
im = ax[2,3].pcolormesh(lon,lat,data[11,:,:])

cb = plt.colorbar(p, extend="both")

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3, ncols=4, sharex=True, sharey=True)
im = ax[0,0].pcolormesh(lon,lat,data[0,:,:])
im = ax[0,1].pcolormesh(lon,lat,data[1,:,:])
im = ax[0,2].pcolormesh(lon,lat,data[2,:,:])
im = ax[0,3].pcolormesh(lon,lat,data[3,:,:])
im = ax[1,0].pcolormesh(lon,lat,data[4,:,:])
im = ax[1,1].pcolormesh(lon,lat,data[5,:,:])
im = ax[1,2].pcolormesh(lon,lat,data[6,:,:])
im = ax[1,3].pcolormesh(lon,lat,data[7,:,:])
im = ax[2,0].pcolormesh(lon,lat,data[8,:,:])
im = ax[2,1].pcolormesh(lon,lat,data[9,:,:])
im = ax[2,2].pcolormesh(lon,lat,data[10,:,:])
im = ax[2,3].pcolormesh(lon,lat,data[11,:,:])

ax[0,0].set_title('January')
ax[0,1].set_title('February')
ax[0,2].set_title('March')
ax[0,3].set_title('Abril')
ax[1,0].set_title('May')
ax[1,1].set_title('June')
ax[1,2].set_title('July')
ax[1,3].set_title('August')
ax[2,0].set_title('September')
ax[2,1].set_title('October')
ax[2,2].set_title('November')
ax[2,3].set_title('December')

cb = plt.colorbar(p, extend="both")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-f198e89f20d5> in <module>
#      28 cb = plt.colorbar(p, extend="both")
#      29
# ---> 30 ax[2,3].set_colorbar(p, extend="both")
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_colorbar'
