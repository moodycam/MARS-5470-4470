# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr

# %%
file = '/Users/abigailpozulp/Desktop/duet_names.xlsx'
duet_names = pd.read_excel(file)

# %%
duet_names.head(3)
# Out:
#   Note Order 20190215_d1 20190215_d2 20190215_d3 20190215_d4 20190215_d5  \
# 0         n1       preet        quip     whurrop       Chuff       Chuff
# 1         n2       scraw       trill       hello        Wooo        Wooo
# 2         n3      yoohoo       chirp       hello         Ahh         Ahh
#
#   20190215_d6 20190215_d7 20190215_d8 20190215_d10     ...      20190324_d20  \
# 0       chuff       preet       preet        chuff     ...             chirp
# 1         woo       scraw       scraw          woo     ...            scream
# 2         ahh      yoohoo      yoohoo          ahh     ...               ahh
#
#   20190324_d21 20190324_d23 20190324_d26 20190324_d27 20190324_d28  \
# 0        chirp        chuff         bray        trill        trill
# 1         bray        chuff          caw        squee        chirp
# 2          caw          woo        grawp       chirp         brill
#
#   20190324_d29 20190324_d30 20190324_d34 20190324_d35
# ...

# %% [markdown]
# ### above you can see the dataset with each duet as a column, and each row as a 'note', there are 35 unique notes that I have given names to. I don't think a spreadsheet of words will be useful so I have translated them into numeric identification numbers. I will upload that spreadsheeet below

# %%
file = '/Users/abigailpozulp/Desktop/Duets.xlsx'
Duets = pd.read_excel(file)

# %%
Duets.head(6)
# Out:
#   note_order  20190215_d1  20190215_d2  20190215_d3  20190215_d4  20190215_d5  \
# 0         n1          3.0          6.0         16.0         24.0         24.0
# 1         n2         20.0          7.0         28.0         12.0         12.0
# 2         n3          1.0          5.0         28.0         22.0         22.0
# 3         n4          2.0          5.0         24.0         29.0         29.0
# 4         n5         24.0          1.0         14.0          NaN          NaN
# 5         n6          NaN          4.0         24.0          NaN          NaN
#
#    20190215_d6  20190215_d7  20190215_d8  20190215_d10      ...       \
# 0         24.0          3.0          3.0          24.0      ...
# 1         12.0         20.0         20.0          12.0      ...
# 2         22.0          1.0          1.0          22.0      ...
# 3         29.0          2.0         15.0          29.0      ...
# 4          NaN         24.0         24.0           NaN      ...
# ...

# %%
Duets.shape
# Out:
# (17, 96)

# %%
x = np.array(Duets['20190215_d1'])

# %%
x
# Out:
# array([ 3., 20.,  1.,  2., 24., nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan])

# %% [markdown]
# ### Now that I have my dataset, I would like to make a plot showing the note progression of each duet with an individual color marker for each of the 37 note types.

# %%
Duets.plot.area(stacked=True)

# %% [markdown]
# ### that didn't work, maybe because the ID numbers are adding weight to the overall note score rather than being treated as non-numeric identifiers

# %% [markdown]
# # Going to transpose the dataset and see if that helps

# %%
file = '/Users/abigailpozulp/Desktop/duet_names.xlsx'
duet_names = pd.read_excel(file)

# %%
duet_names.head(3)
# Out:
#      Duet Name       n1     n2      n3      n4      n5     n6     n7     n8  \
# 0  20190215_d1    preet  scraw  yoohoo  yeehaw     caw    NaN    NaN    NaN
# 1  20190215_d2     quip  trill   chirp   chirp  yoohoo   bray    NaN    NaN
# 2  20190215_d3  whurrop  hello   hello   chuff     raw  chuff  chuff  chuff
#
#      n9   n10   n11  n12  n13  n14  n15  n16  n17
# 0   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  wooo  ahhh  honk  NaN  NaN  NaN  NaN  NaN  NaN

# %%
file = '/Users/abigailpozulp/Desktop/Duets.xlsx'
Duets = pd.read_excel(file)

# %%
Duets.head(3)
# Out:
#          duets  n0  n1  n2    n3    n4    n5    n6    n7    n8    n9   n10  \
# 0  20190215_d1   3  20   1   2.0  24.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1  20190215_d2   6   7   5   5.0   1.0   4.0   NaN   NaN   NaN   NaN   NaN
# 2  20190215_d3  16  28  28  24.0  14.0  24.0  24.0  24.0  12.0  22.0  29.0
#
#    n11  n12  n13  n14  n15  n16
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN

# %%
print(duet_names.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 18 columns):
# Duet Name    96 non-null object
# n1           96 non-null object
# n2           96 non-null object
# n3           96 non-null object
# n4           90 non-null object
# n5           56 non-null object
# n6           43 non-null object
# n7           31 non-null object
# n8           19 non-null object
# n9           12 non-null object
# n10          9 non-null object
# n11          5 non-null object
# n12          2 non-null object
# n13          2 non-null object
# n14          2 non-null object
# n15          1 non-null object
# n16          0 non-null float64
# n17          0 non-null float64
# dtypes: float64(2), object(16)
# memory usage: 13.6+ KB
# None

# %%
print(duet_names['n1'].unique())
# This are all the possible first notes
# Out:
# ['preet' 'quip' 'whurrop' 'chuff' 'garble' 'caw' 'oi' 'chirp' 'trill'
#  'burr' 'yeehaw' 'brill' 'prawn' 'wop' 'squee' 'scraw' 'scream' 'purr'
#  'croak' 'quill' 'browk' 'bray']

# %%
print(duet_names.groupby('n1').size())
# this shows us how many times the notes were used in n1
# Out:
# n1
# bray        1
# brill       2
# browk       2
# burr        9
# caw         4
# chirp      18
# chuff      14
# croak       1
# garble      2
# oi          2
# prawn       2
# preet       4
# purr        1
# quill       4
# quip        7
# scraw       1
# scream      2
# squee       1
# trill      12
# whurrop     2
# wop         1
# yeehaw      4
# dtype: int64

# %%
import seaborn as sns
import copy
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(duet_names['n1'],label="Count")
plt.show()
#plot of how many times each note type was used to begin a duet

# %%
# let's see how many null values are in the set
print(duet_names.isnull().sum())
# Out:
# Duet Name     0
# n1            0
# n2            0
# n3            0
# n4            6
# n5           40
# n6           53
# n7           65
# n8           77
# n9           84
# n10          87
# n11          91
# n12          94
# n13          94
# n14          94
# n15          95
# n16          96
# n17          96
# dtype: int64

# %% [markdown]
# # There are some issues with using a dataset for this kind of categorical data, I will try making a series of lists instead

# %%
d1 = "preet scraw yoohoo yeehaw caw"         
d2 = 'quip trill chirp chirp yoohoo bray'        
d3 = 'whurrop hello hello chuff raw chuff chuff chuff woo ahh honk'   
d4 = 'chuff woo ahh honk'          
d5 = 'chuff woo ahh honk'          
d6 = 'chuff woo ahh honk'          
d7 = 'preet scraw yoohoo yeehaw caw'         
d8 = 'preet scraw yoohoo whurr chuff wop wop wop'      
d9 = 'chuff woo ahh honk'          
d10 = 'chuff woo ahh honk'          
d11 = 'chuff whurr ahh honk'          
d12 = 'chuff whurr ahh honk'          
d13 = 'chuff woo ahh honk'          
d14= 'garble trill chuff raw'          
d15= 'chuff woo ahh honk'          
d16= 'chuff whurr ahh honk'          
d17= 'caw whurr ahh honk'          
d18= 'oi oi chirp trill ahah oi oi oi hello hello'    
d19= 'chirp meow yoohoo whurr'          
d20= 'chirp chirp yoohoo bray caw meow'        
d21= 'caw chirp chirp ahah chirp bray caw eyah preet quip eyah'   
d22= 'chirp burr chirp brill ahah'         
d23= 'chirp whurrop eyah ahah eyah ahah'        
d24= 'chirp chirp burr chirp brill ahah caw yeehaw yeehaw meow'    
d25= 'trill burr scream caw yeehaw yeehaw bray caw meow'     
d26= 'burr chirp brill ahah'          
d27= 'burr chirp brill ahah'          
d28= 'garble ahah whurrop eyah'          
d29= 'trill chirp chirp scream yeehaw bray caw'       
d30= 'chirp bray caw oi'          
d31= 'caw yeehaw chirp yeehaw whurrop caw'        
d32= 'trill chirp scream caw yeehaw yeehaw'        
d33= 'chirp eyah eyah eyah bray caw grawp'       
d34= 'yeehaw grawp scream nyah yoohoo bray caw meow'      
d35= 'chirp chirp wop wop wop wop preet yeet yoohoo'     
d36= 'trill chirp scream chuff yeehaw yeehaw bray chuff meow'     
d37= 'chirp burr chirp brill ahh'         
d38= 'burr chirp brill ahh'          
d39= 'burr chirp brill ahh'          
d40= 'chirp brill burr chirp brill ahah eyah ahah eyah meow'    
d41= 'burr chirp brill ahah'          
d42= 'trill chirp trill chirp brill chuff chirp eyah'      
d43= 'brill caw chirp bray'          
d44= 'chirp scream chuff yeehaw yeehaw bray ahh meow'      
d45= 'chirp scream yeehaw bray buzz meow'        
d46= 'prawn chirp scream chuff yeehaw chuff meow'       
d47= 'chuff woo ahh honk'          
d48= 'wop wop preet scraw yoohoo yeehaw caw'       
d49= 'trill uhuh preet scraw yoohoo yeehaw caw'       
d50= 'chirp squee yeehaw bray chuff'         
d51= 'quip scream chuff yeehaw yeehaw bray chuff meow'      
d52= 'quip scream chuff yeehaw yeehaw bray  buzz meow'      
d53= 'chuff yeehaw yeehaw'           
d54= 'burr ahah whurrop sob'          
d55= 'squee chuff chirp hyahh yoohoo bray chuff'       
d56= 'scraw yeehaw yeehaw garble grawp buzz'        
d57= 'yeehaw yeehaw yeehaw yeehaw bray buzz meow'       
d58= 'brill chirp brill ahh'          
d59= 'quip squee chuff chirp yeet yoohoo bray caw'      
d60= 'scream chuff yeehaw yeehaw bray'         
d61= 'trill chirp scream quip bray  meow'        
d62= 'prawn chirp scream chuff bray oi meow'       
d63= 'trill chirp scream bray'          
d64= 'trill chirp scream bray'          
d65= 'burr chirp brill ahah'          
d66= 'burr chirp brill ahah'          
d67= 'whurrop ahh meow caw'          
d68= 'trill wop wop wop preet scraw yoohoo'       
d69= 'quip quip quip oi chirp trill ahah eyah uhuh sob'    
d70= 'yeehaw ahh chirp whurrop yoohoo'         
d71= 'yeehaw ahh chirp whurrop yoohoo quip  oi quip  bray oi garble ahah meow scraw'
d72= 'quip chirp chirp whurrop quip bray scraw whurrop scraw caw nyah yeehaw grawp chirp'
d73= 'purr quip quip quip yeehaw grawp'        
d74= 'caw chirp nyah yoohoo bray caw'        
d75= 'chirp honk chuff eyah'          
d76= 'croak quill ahh eyah sob'         
d77= 'quill ahh eyah'           
d78= 'quill ahh eyah sob'          
d79= 'quip uhuh preet scraw yoohoo yeehaw caw'       
d80= 'preet scraw yoohoo yeehaw caw'         
d81= 'quill ahah woo sob'          
d82= 'quill ahh eyah sob'          
d83= 'chuff woo ahh honk'          
d84= 'browk oi oi oi hello hello chuff woo ahh hello honk'   
d85= 'browk quill ahah woo sob'         
d86= 'oi oi preet scraw yoohoo yeehaw caw'       
d87= 'chirp scream ahh'           
d88= 'chirp bray caw'           
d89= 'chuff chuff woo ahh honk caw'        
d90= 'bray caw grawp'           
d91= 'trill squee chirp nyah yoohoo'         
d92= 'trill chirp brill grawp eyah'         
d93= 'burr chirp brill'           
d94= 'scream chuff yeehaw yeehaw bray caw meow'       
d95= 'chirp preet chirp brill chuff eyah'        
d96= 'chirp trill sob caw woo'

# %%
## Now split the strings into lists

# %%
d1 = d1.split(' ')
d2= d2.split(' ')
d3= d3.split(' ')
d4= d4.split(' ')
d5= d5.split(' ')
d6= d6.split(' ')
d7= d7.split(' ')
d8= d8.split(' ')
d9= d9.split(' ')
d10= d10.split(' ')
d11= d11.split(' ')
d12= d12.split(' ')
d13= d13.split(' ')
d14= d14.split(' ')
d15= d15.split(' ')
d16= d16.split(' ')
d17= d17.split(' ')
d18= d18.split(' ')
d19= d19.split(' ')
d20= d20.split(' ')
d21= d21.split(' ')
d22= d22.split(' ')
d23= d23.split(' ')
d24= d24.split(' ')
d25= d25.split(' ')
d26= d26.split(' ')
d27= d27.split(' ')
d28= d28.split(' ')
d29= d29.split(' ')
d30= d30.split(' ')
d31= d31.split(' ')
d32= d32.split(' ')
d33= d33.split(' ')
d34= d34.split(' ')
d35= d35.split(' ')
d36= d36.split(' ')
d37= d37.split(' ')
d38= d38.split(' ')
d39= d39.split(' ')
d40= d40.split(' ')
d41= d41.split(' ')
d42= d42.split(' ')
d43= d43.split(' ')
d44= d44.split(' ')
d45= d45.split(' ')
d46= d46.split(' ')
d47= d47.split(' ')
d48= d48.split(' ')
d49= d49.split(' ')
d50= d50.split(' ')
d51= d51.split(' ')
d52= d52.split(' ')
d53= d53.split(' ')
d54= d54.split(' ')
d55= d55.split(' ')
d56= d56.split(' ')
d57= d57.split(' ')
d58= d58.split(' ')
d59= d59.split(' ')
d60= d60.split(' ')
d61= d61.split(' ')
d62= d62.split(' ')
d63= d63.split(' ')
d64 =d64.split(' ')
d65= d65.split(' ')
d66= d66.split(' ')
d67= d67.split(' ')
d68= d68.split(' ')
d69 =d69.split(' ')
d70= d70.split(' ')
d71= d71.split(' ')
d72= d72.split(' ')
d73= d73.split(' ')
d74= d74.split(' ')
d75= d75.split(' ')
d76= d76.split(' ')
d77= d77.split(' ')
d78= d78.split(' ')
d79= d79.split(' ')
d80= d80.split(' ')
d81= d81.split(' ')
d82= d82.split(' ')
d83= d83.split(' ')
d84 =d84.split(' ')
d85= d85.split(' ')
d86= d86.split(' ')
d87= d87.split(' ')
d88= d88.split(' ')
d89= d89.split(' ')
d90= d90.split(' ')
d91= d91.split(' ')
d92= d92.split(' ')
d93= d93.split(' ')
d94= d94.split(' ')
d95= d95.split(' ')
d96= d96.split(' ')

# %%
unique_words = set(d1)
print(unique_words)
# Out:
# {'yoohoo', 'scraw', 'yeehaw', 'caw', 'preet'}

# %% [markdown]
# # actually I probably didn't need to make a bunch of lists

# %% [markdown]
# #### Word Embedding is a language modeling technique used for mapping words to vectors of real numbers. It represents words or phrases in vector space with several dimensions. Word embeddings can be generated using various methods like neural networks, co-occurrence matrix, probabilistic models, etc.
#
# Word2Vec consists of models for generating word embedding. These models are shallow two layer neural networks having one input layer, one hidden layer and one output layer. Word2Vec utilizes two architectures :
#
# CBOW (Continuous Bag of Words) : CBOW model predicts the current word given context words within specific window. The input layer contains the context words and the output layer contains the current word. The hidden layer contains the number of dimensions in which we want to represent current word present at the output layer.
#
#
#
# Skip Gram : Skip gram predicts the surrounding context words within specific window given current word. The input layer contains the current word and the output layer contains the context words. The hidden layer contains the number of dimensions in which we want to represent current word present at the input layer.
#
# The basic idea of word embedding is words that occur in similar context tend to be closer to each other in vector space. For generating word vectors in Python, modules needed are nltk and gensim.
