# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
file = "C:\\Users\Bridgett\Desktop\Major_Ecoregions.xlsx"
Major_ecoregions = pd.read_excel(file)

# %%
Major_ecoregions
# Out:
#     Unnamed: 0                                                  0  \
# 0            0              Tamaulipan Mixed Deciduous Thornscrub
# 1            1                       Tamaulipan Savanna Grassland
# 2            2                   Tamaulipan Calcareous Thornscrub
# 3            3                              Tamaulipan Floodplain
# 4            4                                 Tamulipan Ramadero
# 5            5                 Mainly Natural Azonal Mapped Types
# 6            6  Agricultural and other Human-related Mapped Types
# 7            7               Tamaulipan Closed Depression Wetland
# 8            8                       Texas Saline Coastal Prairie
# 9            9          Texas Coast Salt and Brackish Tidal Marsh
# 10          10             Texas Coast Dune and Coastal Grassland
# 11          11      Rio Grande Delta Thorn Woodland and Shrubland
# 12          12                                Texas Coastal Beach
# 13          13  Central and South Texas Coastal Fringe Forest ...
# 14          14      Southeastern Coastal Plain Interdunal Wetland
# 15          15          South Texas Salt and Brackish Tidal Flats
# 16          16                                   Tamaulipan Lomas
# 17          17              Tamaulipan Palm Grove Riparian Forest
# 18          18                             Tamaulipan Saline Lake
# 19          19                       Tamaulipan Saline Thornscrub
# 20          20                       Tamaulipan Caliche Grassland
#
#     Major_ecoreg_area  Major_ecoreg_percent_area
# 0        6.187106e+08                   5.327991
# 1        2.467284e+09                  21.246872
# 2        4.422166e+08                   3.808123
# 3        2.022538e+08                   1.741697
# 4        1.765012e+08                   1.519930
# 5        1.821777e+09                  15.688131
# 6        3.570055e+09                  30.743329
# 7        1.499307e+07                   0.129112
# 8        5.357306e+08                   4.613413
# 9        2.595099e+08                   2.234754
# 10       2.321518e+07                   0.199916
# 11       1.637675e+06                   0.014103
# 12       7.274650e+08                   6.264523
# 13       8.874322e+06                   0.076421
# 14       3.764550e+08                   3.241821
# 15       6.835801e+07                   0.588661
# 16       6.491596e+05                   0.005590
# 17       1.377513e+07                   0.118624
# 18       1.591856e+08                   1.370818
# 19       1.075489e+08                   0.926151
# 20       1.625977e+07                   0.140020

# %%
Major_ecoregions.drop(Major_ecoregions.columns[[0]], axis=1)
# Out:
#                                                     0  Major_ecoreg_area  \
# 0               Tamaulipan Mixed Deciduous Thornscrub       6.187106e+08
# 1                        Tamaulipan Savanna Grassland       2.467284e+09
# 2                    Tamaulipan Calcareous Thornscrub       4.422166e+08
# 3                               Tamaulipan Floodplain       2.022538e+08
# 4                                  Tamulipan Ramadero       1.765012e+08
# 5                  Mainly Natural Azonal Mapped Types       1.821777e+09
# 6   Agricultural and other Human-related Mapped Types       3.570055e+09
# 7                Tamaulipan Closed Depression Wetland       1.499307e+07
# 8                        Texas Saline Coastal Prairie       5.357306e+08
# 9           Texas Coast Salt and Brackish Tidal Marsh       2.595099e+08
# 10             Texas Coast Dune and Coastal Grassland       2.321518e+07
# 11      Rio Grande Delta Thorn Woodland and Shrubland       1.637675e+06
# 12                                Texas Coastal Beach       7.274650e+08
# 13  Central and South Texas Coastal Fringe Forest ...       8.874322e+06
# 14      Southeastern Coastal Plain Interdunal Wetland       3.764550e+08
# 15          South Texas Salt and Brackish Tidal Flats       6.835801e+07
# 16                                   Tamaulipan Lomas       6.491596e+05
# 17              Tamaulipan Palm Grove Riparian Forest       1.377513e+07
# 18                             Tamaulipan Saline Lake       1.591856e+08
# 19                       Tamaulipan Saline Thornscrub       1.075489e+08
# 20                       Tamaulipan Caliche Grassland       1.625977e+07
#
#     Major_ecoreg_percent_area
# 0                    5.327991
# 1                   21.246872
# 2                    3.808123
# 3                    1.741697
# 4                    1.519930
# 5                   15.688131
# 6                   30.743329
# 7                    0.129112
# 8                    4.613413
# 9                    2.234754
# 10                   0.199916
# 11                   0.014103
# 12                   6.264523
# 13                   0.076421
# 14                   3.241821
# 15                   0.588661
# 16                   0.005590
# 17                   0.118624
# 18                   1.370818
# 19                   0.926151
# 20                   0.140020

# %%
Major_ecoregions.columns = ['Index','Major Ecoregion', 'Major_ecoreg_area', 'Major_ecoreg_percent_area']

# %%
Major_ecoregions
# Out:
#     Index                                    Major Ecoregion  \
# 0       0              Tamaulipan Mixed Deciduous Thornscrub
# 1       1                       Tamaulipan Savanna Grassland
# 2       2                   Tamaulipan Calcareous Thornscrub
# 3       3                              Tamaulipan Floodplain
# 4       4                                 Tamulipan Ramadero
# 5       5                 Mainly Natural Azonal Mapped Types
# 6       6  Agricultural and other Human-related Mapped Types
# 7       7               Tamaulipan Closed Depression Wetland
# 8       8                       Texas Saline Coastal Prairie
# 9       9          Texas Coast Salt and Brackish Tidal Marsh
# 10     10             Texas Coast Dune and Coastal Grassland
# 11     11      Rio Grande Delta Thorn Woodland and Shrubland
# 12     12                                Texas Coastal Beach
# 13     13  Central and South Texas Coastal Fringe Forest ...
# 14     14      Southeastern Coastal Plain Interdunal Wetland
# 15     15          South Texas Salt and Brackish Tidal Flats
# 16     16                                   Tamaulipan Lomas
# 17     17              Tamaulipan Palm Grove Riparian Forest
# 18     18                             Tamaulipan Saline Lake
# 19     19                       Tamaulipan Saline Thornscrub
# 20     20                       Tamaulipan Caliche Grassland
#
#     Major_ecoreg_area  Major_ecoreg_percent_area
# 0        6.187106e+08                   5.327991
# 1        2.467284e+09                  21.246872
# 2        4.422166e+08                   3.808123
# 3        2.022538e+08                   1.741697
# 4        1.765012e+08                   1.519930
# 5        1.821777e+09                  15.688131
# 6        3.570055e+09                  30.743329
# 7        1.499307e+07                   0.129112
# 8        5.357306e+08                   4.613413
# 9        2.595099e+08                   2.234754
# 10       2.321518e+07                   0.199916
# 11       1.637675e+06                   0.014103
# 12       7.274650e+08                   6.264523
# 13       8.874322e+06                   0.076421
# 14       3.764550e+08                   3.241821
# 15       6.835801e+07                   0.588661
# 16       6.491596e+05                   0.005590
# 17       1.377513e+07                   0.118624
# 18       1.591856e+08                   1.370818
# 19       1.075489e+08                   0.926151
# 20       1.625977e+07                   0.140020

# %%
Major_ecoregions.drop(Major_ecoregions.columns[[0]], axis=1)
# Out:
#                                       Major Ecoregion  Major_ecoreg_area  \
# 0               Tamaulipan Mixed Deciduous Thornscrub       6.187106e+08
# 1                        Tamaulipan Savanna Grassland       2.467284e+09
# 2                    Tamaulipan Calcareous Thornscrub       4.422166e+08
# 3                               Tamaulipan Floodplain       2.022538e+08
# 4                                  Tamulipan Ramadero       1.765012e+08
# 5                  Mainly Natural Azonal Mapped Types       1.821777e+09
# 6   Agricultural and other Human-related Mapped Types       3.570055e+09
# 7                Tamaulipan Closed Depression Wetland       1.499307e+07
# 8                        Texas Saline Coastal Prairie       5.357306e+08
# 9           Texas Coast Salt and Brackish Tidal Marsh       2.595099e+08
# 10             Texas Coast Dune and Coastal Grassland       2.321518e+07
# 11      Rio Grande Delta Thorn Woodland and Shrubland       1.637675e+06
# 12                                Texas Coastal Beach       7.274650e+08
# 13  Central and South Texas Coastal Fringe Forest ...       8.874322e+06
# 14      Southeastern Coastal Plain Interdunal Wetland       3.764550e+08
# 15          South Texas Salt and Brackish Tidal Flats       6.835801e+07
# 16                                   Tamaulipan Lomas       6.491596e+05
# 17              Tamaulipan Palm Grove Riparian Forest       1.377513e+07
# 18                             Tamaulipan Saline Lake       1.591856e+08
# 19                       Tamaulipan Saline Thornscrub       1.075489e+08
# 20                       Tamaulipan Caliche Grassland       1.625977e+07
#
#     Major_ecoreg_percent_area
# 0                    5.327991
# 1                   21.246872
# 2                    3.808123
# 3                    1.741697
# 4                    1.519930
# 5                   15.688131
# 6                   30.743329
# 7                    0.129112
# 8                    4.613413
# 9                    2.234754
# 10                   0.199916
# 11                   0.014103
# 12                   6.264523
# 13                   0.076421
# 14                   3.241821
# 15                   0.588661
# 16                   0.005590
# 17                   0.118624
# 18                   1.370818
# 19                   0.926151
# 20                   0.140020

# %%
file1 = "C:\\Users\Bridgett\Desktop\Sub_Ecoregions.xlsx"
Sub_ecoregions = pd.read_excel(file1)

# %%
Sub_ecoregions
# Out:
#     Unnamed: 0      0  Sub_ecoreg_area  Sub_ecoreg_percent_area
# 0            0   7004     4.031171e+08                 3.471420
# 1            1   7005     2.155935e+08                 1.856571
# 2            2   7103     9.045338e+07                 0.778934
# 3            3   7104     1.451511e+09                12.499605
# 4            4   7105     2.628441e+08                 2.263467
# 5            5   7107     6.624750e+08                 5.704866
# 6            6   7204     3.311050e+08                 2.851292
# 7            7   7205     7.181243e+07                 0.618409
# 8            8   7207     3.929914e+07                 0.338422
# 9            9   7402     5.794127e+07                 0.498958
# 10          10   7403     1.080143e+07                 0.093016
# 11          11   7404     5.430825e+07                 0.467672
# 12          12   7405     1.208247e+07                 0.104047
# 13          13   7406     4.634350e+07                 0.399084
# 14          14   7602     2.136512e+07                 0.183984
# 15          15   7604     6.462205e+07                 0.556489
# 16          16   7605     1.442801e+07                 0.124246
# 17          17   7606     7.608163e+07                 0.655173
# 18          18   9000     4.553257e+07                 0.392101
# 19          19   9007     2.285809e+07                 0.196841
# 20          20   9104     2.451315e+06                 0.021109
# 21          21   9106     2.995576e+06                 0.025796
# 22          22   9124     1.497807e+06                 0.012898
# 23          23   9187     1.569646e+09                13.516917
# 24          24   9304     2.643974e+07                 0.227684
# 25          25   9307     2.635799e+09                22.698033
# 26          26   9410     1.634979e+08                 1.407953
# 27          27   9411     7.367331e+08                 6.344335
# 28          28   9600     1.722560e+08                 1.483373
# 29          29  10004     9.022668e+06                 0.077698
# ..         ...    ...              ...                      ...
# 38          38   6307     7.145779e+08                 6.153547
# 39          39   7407     2.074264e+06                 0.017862
# 40          40   7802     2.187590e+07                 0.188383
# 41          41   7804     1.205899e+06                 0.010385
# 42          42   7805     1.333847e+05                 0.001149
# 43          43   9107     1.540955e+06                 0.013270
# 44          44   9128     1.084280e+06                 0.009337
# 45          45   9317     7.585659e+06                 0.065323
# 46          46   5606     1.228304e+06                 0.010577
# 47          47   5616     4.489034e+06                 0.038657
# 48          48   6100     1.637675e+06                 0.014103
# 49          49   6200     1.280265e+07                 0.110249
# 50          50   6306     8.439571e+04                 0.000727
# 51          51   6405     4.082341e+07                 0.351548
# 52          52   6507     8.874322e+06                 0.076421
# 53          53   6600     3.212256e+08                 2.766216
# 54          54   6610     5.522943e+07                 0.475605
# 55          55   7305     5.447696e+07                 0.469125
# 56          56   7306     2.142379e+06                 0.018449
# 57          57   7307     1.173867e+07                 0.101087
# 58          58   7502     6.491596e+05                 0.005590
# 59          59   7700     7.603800e+06                 0.065480
# 60          60   7707     6.171325e+06                 0.053144
# 61          61   9204     1.287347e+06                 0.011086
# 62          62   6806     1.591856e+08                 1.370818
# 63          63   7607     4.400000e+03                 0.000038
# 64          64   6402     6.613329e+07                 0.569503
# 65          65   6403     5.921901e+05                 0.005100
# 66          66   6707     1.625977e+07                 0.140020
# 67          67   9116     6.273547e+05                 0.005402
#
# [68 rows x 4 columns]

# %%
Major_ecoregions.columns = ['Index','Veg_ID', 'Sub_ecoreg_area', 'Sub_ecoreg_percent_area']

# %%
Major_ecoregions.drop(Major_ecoregions.columns[[0]], axis=1)
# Out:
#                                                Veg_ID  Sub_ecoreg_area  \
# 0               Tamaulipan Mixed Deciduous Thornscrub     6.187106e+08
# 1                        Tamaulipan Savanna Grassland     2.467284e+09
# 2                    Tamaulipan Calcareous Thornscrub     4.422166e+08
# 3                               Tamaulipan Floodplain     2.022538e+08
# 4                                  Tamulipan Ramadero     1.765012e+08
# 5                  Mainly Natural Azonal Mapped Types     1.821777e+09
# 6   Agricultural and other Human-related Mapped Types     3.570055e+09
# 7                Tamaulipan Closed Depression Wetland     1.499307e+07
# 8                        Texas Saline Coastal Prairie     5.357306e+08
# 9           Texas Coast Salt and Brackish Tidal Marsh     2.595099e+08
# 10             Texas Coast Dune and Coastal Grassland     2.321518e+07
# 11      Rio Grande Delta Thorn Woodland and Shrubland     1.637675e+06
# 12                                Texas Coastal Beach     7.274650e+08
# 13  Central and South Texas Coastal Fringe Forest ...     8.874322e+06
# 14      Southeastern Coastal Plain Interdunal Wetland     3.764550e+08
# 15          South Texas Salt and Brackish Tidal Flats     6.835801e+07
# 16                                   Tamaulipan Lomas     6.491596e+05
# 17              Tamaulipan Palm Grove Riparian Forest     1.377513e+07
# 18                             Tamaulipan Saline Lake     1.591856e+08
# 19                       Tamaulipan Saline Thornscrub     1.075489e+08
# 20                       Tamaulipan Caliche Grassland     1.625977e+07
#
#     Sub_ecoreg_percent_area
# 0                  5.327991
# 1                 21.246872
# 2                  3.808123
# 3                  1.741697
# 4                  1.519930
# 5                 15.688131
# 6                 30.743329
# 7                  0.129112
# 8                  4.613413
# 9                  2.234754
# 10                 0.199916
# 11                 0.014103
# 12                 6.264523
# 13                 0.076421
# 14                 3.241821
# 15                 0.588661
# 16                 0.005590
# 17                 0.118624
# 18                 1.370818
# 19                 0.926151
# 20                 0.140020

# %%
Major_Ecoregions = Major_ecoregions.pivot_table(index=[0])
Major_Ecoregions.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-36978e154d18> in <module>()
# ----> 1 Major_Ecoregions = Major_ecoregions.pivot_table(index=['Year'])
#       2 Major_Ecoregions.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5757                            aggfunc=aggfunc, fill_value=fill_value,
#    5758                            margins=margins, dropna=dropna,
# -> 5759                            margins_name=margins_name)
#    5760
#    5761     def stack(self, level=-1, dropna=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      79         values = list(values)
#      80
# ---> 81     grouped = data.groupby(keys, observed=False)
#      82     agged = grouped.agg(aggfunc)
#      83     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     576                 in_axis, name, level, gpr = False, None, gpr, None
#     577             else:
# --> 578                 raise KeyError(gpr)
#     579         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     580             # Add key to exclusions
#
# KeyError: 'Year'

# %%
ax = Major_ecoregions.plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

  # Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

  # Set x-axis label
ax.set_xlabel("Total Area (Meters)", labelpad=20, weight='bold', size=12)

  # Set y-axis label
ax.set_ylabel("Major Ecoregions", labelpad=20, weight='bold', size=12)

  # Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# C:\Users\Bridgett\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-19a9a40ef8fd> in <module>()
#      22
#      23   # Format y-axis label
# ---> 24 ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
#
# NameError: name 'StrMethodFormatter' is not defined
