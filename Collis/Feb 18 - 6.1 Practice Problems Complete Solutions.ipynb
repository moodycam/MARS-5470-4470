# %% [markdown]
# Lec 6.1 All Challenge Problems
#
# Using the 1980 monthly SST netcdf file we used last time:
#
# 1. Take the annual mean and plot it with the correct lat and lon. Use a different colormap than the default. Add axes labels, a colorbar and title. In the title, include what the plotted variable is and the units.
#
# 2. Take seasonal averages: DJF, etc. Plot the four seasons in a 2x2 plot of subplots, label each plot and put on one colorbar for all the plots, ends extended, with a min value of 0 and a max of 30. Make a descriptive supertitle (suptitle) for all the plots. Would it be correct to label these plots Winter, etc?
#
# 3. Mask out regions outside of the tropics (google definition of tropics) and plot the annual mean again. Adjust the font size of your axes labels and title. Adjust the axis limits to be constrained to the data (i.e. no whitespace).
#
# 4. Mask out the tropics and plot again.
#
# 5. (Advanced) Find the grid cell closest to us. How big is this cell in square km and miles? Plot the seasonal cycle of SST. What are our local seasonal averages, according to this model? Annual Mean? Are they realistic? What data sources could you use to validate this?

# %% [markdown]
# # 1. Take the annual mean and plot it with the correct lat and lon. Use a different colormap than the default. Add axes labels, a colorbar and title. In the title, include what the plotted variable is and the units.

# %%
#Location: C:\Bridgett\Bridgett\Introduction to Scientific computing
#Name:CESM.003.SST.1980.nc

#Take the annual mean and plot it with the correct lat and lon.
#To create a plot the first step is to import matplotlib and numpy.
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
#Now we need to use the plt function 
#Make the plot
plt.figure()

# %%
#Show the plot
plt.subplot()

# %%
#make subplot bigger on the screen:add figsize= in figure ()
plt.figure(figsize=(8,6))
plt.subplot()

# %%
#Now we need to take the anual mean and display it on the plot
#To do this we need to first create an array with our data
#To create an array we need to import xarray

import xarray as xr

#Assign data to a variable
#Location: C:\Bridgett\Bridgett\Introduction to Scientific computing
#Name:CESM.003.SST.1980.nc
import xarray as xr
data=xr.open_dataset('C:\Bridgett\Bridgett\Introduction to Scientific computing\CESM.003.SST.1980.nc')
print(data)
lat = np.array(data.lat)
lon = np.array(data.lon)
data = np.array(data.SST)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 180, lon: 360, time: 12)
# Coordinates:
#   * lon      (lon) float64 0.0 1.0 2.0 3.0 4.0 ... 355.0 356.0 357.0 358.0 359.0
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * time     (time) datetime64[ns] 1980-01-31 1980-02-29 ... 1980-12-31
# Data variables:
#     SST      (time, lat, lon) float32 ...

# %%
#Take the annual mean and plot it with the correct lat and lon.
plt.pcolormesh(data[6,:,:])

# %%
plt.figure()

# %%
plt.subplots(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-9d10cccc795f> in <module>()
# ----> 1 plt.subplots(data)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1185     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1186                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1187                        gridspec_kw=gridspec_kw)
#    1188     return fig, axs
#    1189
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1360
#    1361         # Create array to hold all axes.
# -> 1362         axarr = np.empty((nrows, ncols), dtype=object)
#    1363         for row in range(nrows):
#    1364             for col in range(ncols):
#
# ...

# %%
# Now, I want a pcolormap of the anual mean.
meandata = np.mean(data, axis=0)
plt.pcolormesh(meandata)

#This has the data plotted, but the axis is only an index used for the raw dataset.

# %%
#We want Lat values(-80 to 80) on y axis /Lon values (0 to 350)
meandata = np.mean(data, axis=0)
plt.pcolormesh(lon, lat, meandata)

# %%
#Use a different colormap than the default. 
#Add axes labels, a colorbar and title. 
#In the title, include what the plotted variable is and the units.

meandata = np.mean(data, axis=0)
plt.pcolormesh(lon, lat, meandata, colormap='plasma')
plt.colorbar()

# %%
#Use a different colormap than the default. 
#Add axes labels, a colorbar and title. 
#In the title, include what the plotted variable is and the units.

meandata = np.mean(data, axis=0)
plt.pcolormesh(lon, lat, meandata, cmap='plasma')
plt.colorbar()

#cb.set_label('Sea Surface Temperature [$^{o}$C]')

# %%
meandata = np.mean(data, axis=0)
plt.pcolormesh(lon, lat, meandata, cmap='plasma')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
#ax.set_title('1980 Sea Surface Temperature in [$^{o}$C]')

# %%
ax=plt.pcolormesh(lon, lat, meandata, cmap='plasma')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Sea Surface Temperature in [$^{o}$C]')

# %%
# 1. Take the annual mean and plot it with the correct lat and lon. 
#    Use a different colormap than the default. Add axes labels, a colorbar and title. 
#    In the title, include what the plotted variable is and the units.



fig,ax=plt.subplots()
p=plt.pcolormesh(lon, lat, meandata, cmap='plasma')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Annual Mean Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')

# %% [markdown]
# # 2. Take seasonal averages: DJF, etc. Plot the four seasons in a 2x2 plot of subplots, label each plot and put on one colorbar for all the plots, ends extended, with a min value of 0 and a max of 30. Make a descriptive supertitle (suptitle) for all the plots. Would it be correct to label these plots Winter, etc?

# %%
#Take Seasonal Averages for DJF, 11:3,:,: 
fig,ax=plt.subplots()
winter=np.mean(data[11:3,:,:])
p=plt.pcolormesh(lon, lat, winter, cmap='plasma')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Winter Average Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
# Out:
# C:\Users\Bridgett\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Bridgett\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-630ab52f06d6> in <module>()
#       2 fig,ax=plt.subplots()
#       3 winter=np.mean(data[11:3,:,:])
# ----> 4 p=plt.pcolormesh(lon, lat, winter, cmap='plasma')
#       5 cb=plt.colorbar()
#       6
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pcolormesh(*args, **kwargs)
#    3291                       mplDeprecation)
#    3292     try:
# -> 3293         ret = ax.pcolormesh(*args, **kwargs)
#    3294     finally:
#    3295         ax._hold = washold
#
# ...

# %%
#Take Seasonal Averages for DJF, 11:3,:,: 
fig,ax=plt.subplots()
#winter=np.mean(data[11:3,:,:])
sst_DJF=np.mean(data[(0,1,11),:,:], axis=0)
p=plt.pcolormesh(lon, lat,sst_DJF, cmap='coolwarm')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Winter Average Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
# Out:
# Text(0.5,0,'Longitude')

# %%
#Take seasonal averages: DJF, etc. 
#Plot the four seasons in a 2x2 plot of subplots
#Label each plot and put on one colorbar for all the plots, ends extended
#With a min value of 0 and a max of 30. 
#Make a descriptive supertitle (suptitle) for all the plots.
#Would it be correct to label these plots Winter, etc?

#Now I need to do MAM, JJA, SON

#Take Seasonal Averages for MAM
fig,ax=plt.subplots()
sst_MAM=np.mean(data[(2,3,4),:,:], axis=0)
p=plt.pcolormesh(lon, lat,sst_MAM, cmap='coolwarm')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Spring Average Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
# Out:
# Text(0.5,0,'Longitude')

# %%
#Take Seasonal Averages for JJA
fig,ax=plt.subplots()
sst_JJA=np.mean(data[(5,6,7),:,:], axis=0)
p=plt.pcolormesh(lon, lat,sst_JJA, cmap='coolwarm')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Summer Average Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
# Out:
# Text(0.5,0,'Longitude')

# %%
#Take Seasonal Averages for SON
fig,ax=plt.subplots()
sst_SON=np.mean(data[(8,9,10),:,:], axis=0)
p=plt.pcolormesh(lon, lat,sst_SON, cmap='coolwarm')
cb=plt.colorbar()

cb.set_label('Sea Surface Temperature [$^{o}$C]')
ax.set_title('1980 Fall Average Sea Surface Temperature [$^{o}$C]')
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
# Out:
# Text(0.5,0,'Longitude')

# %%
#Plot the four seasons in a 2x2 plot of subplots
#Label each plot and put on one colorbar for all the plots, ends extended
#With a min value of 0 and a max of 30. 
#Make a descriptive supertitle (suptitle) for all the plots.
#Would it be correct to label these plots Winter, etc?

fig, ax = plt.subplots(figsize=(12,8), nrows=2, ncols=2)
ax[0,0].pcolormesh(sst_DJF)
ax[0,1].pcolormesh(sst_MAM)
ax[1,0].pcolormesh(sst_JJA)
ax[1,1].pcolormesh(sst_SON)

# %%
fig, ax = plt.subplots(figsize=(12,8), nrows=2, ncols=2)

p1=plt.pcolormesh(lon, lat,sst_DJF, cmap='coolwarm')
p2=plt.pcolormesh(lon, lat,sst_MAM, cmap='coolwarm')
p3=plt.pcolormesh(lon, lat,sst_JJA, cmap='coolwarm')
p4=plt.pcolormesh(lon, lat,sst_SON, cmap='coolwarm')

ax[0,0].pcolormesh(p1)
ax[0,1].pcolormesh(p2)
ax[1,0].pcolormesh(p3)
ax[1,1].pcolormesh(p4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-be17abc8a048> in <module>()
#       6 p4=plt.pcolormesh(lon, lat,sst_SON, cmap='coolwarm')
#       7
# ----> 8 ax[0,0].pcolormesh(p1)
#       9 ax[0,1].pcolormesh(p2)
#      10 ax[1,0].pcolormesh(p3)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, *args, **kwargs)
#    6019         allmatch = (shading == 'gouraud')
#    6020
# -> 6021         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8), nrows=2, ncols=2)

p1=plt.pcolormesh(lon, lat,sst_DJF, cmap='coolwarm')
#ax[0,0].pcolormesh(p1)

# %%
#This should be a plot with all subplots filled in
fig, ax = plt.subplots(figsize=(12,8), nrows=2, ncols=2)
ax[0,0].pcolormesh(lon,lat,sst_DJF, cmap='coolwarm')
ax[0,1].pcolormesh(lon,lat,sst_MAM, cmap='coolwarm')
ax[1,0].pcolormesh(lon,lat,sst_JJA, cmap='coolwarm')
ax[1,1].pcolormesh(lon,lat,sst_SON, cmap='coolwarm')

# %%
#Now it needs to have a color bar

fig, ax = plt.subplots(figsize=(12,8), nrows=2, ncols=2)
ax[0,0].pcolormesh(lon,lat,sst_DJF, cmap='coolwarm')
ax[0,0].set_title('Winter')
ax[0,1].pcolormesh(lon,lat,sst_MAM, cmap='coolwarm')
ax[0,1].set_title('Spring')
ax[1,0].pcolormesh(lon,lat,sst_JJA, cmap='coolwarm')
ax[1,0].set_title('Summer')
im=ax[1,1].pcolormesh(lon,lat,sst_SON, cmap='coolwarm')
ax[1,1].set_title('Fall')

#Titles and Subtitles:
fig.suptitle('CESM Sea Surface Temperature (1980)', fontsize=30)
fig.text(0.5, 0.04, 'Longitude', ha='center', fontsize=15)
fig.text(0.04, 0.5, 'Latitude', va='center', rotation='vertical', fontsize=15)

#Colorbar:
cb = fig.colorbar(im,ax=ax, extend = 'both')
cb.set_label('Sea Surface Temperature [$^{o}$C]', fontsize=18)

# %% [markdown]
# # 3. Mask out regions outside of the tropics (google definition of tropics) and plot the annual mean again. Adjust the font size of your axes labels and title. Adjust the axis limits to be constrained to the data (i.e. no whitespace).

# %% [markdown]
# ###### Mask SST data outside the tropics
# #Tropics: (23.4368,-23.4368)
#
# #Tropics= lat>-23.4368 & lat<23.4368
# botTrop= lat>-23.4368
# topTrop= lat<23.4368
# tropics=topTrop & botTrop
# fig, ax = plt.subplots()
# p = ax.pcolormesh(tropics,lon,meandata, cmap="coolwarm",)

# %%
#Mask SST data outside the tropics
#Tropics: (23.4368,-23.4368)

#Tropics= lat>-23.4368 & lat<23.4368
botTrop= lat>-23.4368
topTrop= lat<23.4368
tropics=topTrop | botTrop
fig, ax = plt.subplots()
p = ax.pcolormesh(tropics,lon,meandata, cmap="coolwarm",)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-6ded82d47006> in <module>()
#       7 tropics=topTrop | botTrop
#       8 fig, ax = plt.subplots()
# ----> 9 p = ax.pcolormesh(tropics,lon,meandata, cmap="coolwarm",)
#
# NameError: name 'meandata' is not defined

# %%
trop = 23.4368

(lat> trop) | (lat< (-1*trop))
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True,  True,
# ...

# %%
mask = np.zeros_like(sst_mean)

# %%
lat.shape
# Out:
# (180,)

# %%
sst_mean= np.mean(data, axis=0)

# %%
mask = np.zeros_like(sst_mean)

# %%
#mask = np.zeros_like(sst_mean)
for i in range(360):
    mask[:,i] = (lat> trop) | (lat< (-1*trop))

# %%
plt.pcolormesh(mask)
plt.colorbar()

# %%
#We made this mask because we want to only see SST in the Tropics
#The world view should also be limited to this range

sst_trop = np.ma.masked_where(mask,sst_mean)

# %%
plt.pcolormesh(lon,lat,sst_trop)
plt.colorbar()

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_trop)
plt.xlabel('Lon (Degrees E)', fontsize = 14)
plt.ylabel('Lat', fontsize = 14)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 14)
#plt.ylim([-trop,trop+1]
# Out:
# Text(0.5,1,'1980 Annual Mean SST ($^o$C)')

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_trop)
plt.xlabel('Lon (Degrees E)', fontsize = 14)
plt.ylabel('Lat', fontsize = 14)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 14)
plt.ylim(-1*trop, trop)
# Out:
# (-23.4368, 23.4368)

# %%
mpl.rcParams['font.size'] = 14
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-b9d1eafe7483> in <module>()
# ----> 1 mpl.rcParams['font.size'] = 14
#
# NameError: name 'mpl' is not defined

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 14

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_trop)
plt.xlabel('Lon (Degrees E)', fontsize = 18)
plt.ylabel('Lat', fontsize = 18)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 25)
plt.ylim(-1*trop, trop)
# Out:
# (-23.4368, 23.4368)

# %% [markdown]
# # 4. Mask out the tropics and plot again¶

# %%
#sst_trop = np.ma.masked_where(mask,sst_mean)
mask = np.zeros_like(sst_mean)

# %%
#mask = np.zeros_like(sst_mean)
for i in range(360):
    mask[:,i] = (lat> trop) | (lat< (-1*trop))

# %%
sst_nontrop = np.ma.masked_where(mask,sst_mean)

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_nontrop)
plt.xlabel('Lon (Degrees E)', fontsize = 18)
plt.ylabel('Lat', fontsize = 18)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 25)
# Out:
# Text(0.5,1,'1980 Annual Mean SST ($^o$C)')

# %%
mask.shape
# Out:
# (180, 360)

# %%
#Mask is still masking areas outside the tropics
#for i in range(360):
#    mask[:,i] = (lat> trop) | (lat< (-1*trop))

for i in range(360):
    mask[:,i] = (lat< trop) | (lat> (-1*trop))

# %%
sst_nontrop = np.ma.masked_where(mask,sst_mean)

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_nontrop)
plt.xlabel('Lon (Degrees E)', fontsize = 18)
plt.ylabel('Lat', fontsize = 18)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 25)
# Out:
# Text(0.5,1,'1980 Annual Mean SST ($^o$C)')

# %%
for i in range(360):
    mask[:,i] = (lat< trop) & (lat> (-1*trop))

# %%
sst_nontrop = np.ma.masked_where(mask,sst_mean)

# %%
plt.figure(figsize=(17,5))
plt.pcolormesh(lon,lat,sst_nontrop)
plt.xlabel('Lon (Degrees E)', fontsize = 18)
plt.ylabel('Lat', fontsize = 18)
plt.colorbar()
plt.title('1980 Annual Mean SST ($^o$C)', fontsize = 25)
# Out:
# Text(0.5,1,'1980 Annual Mean SST ($^o$C)')
