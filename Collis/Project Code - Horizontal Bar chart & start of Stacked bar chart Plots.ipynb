# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
file = "C:\\Users\Bridgett\Desktop\MER.xlsx"
MER= pd.read_excel(file)

# %%
MER=MER.drop(MER.columns[[0]], axis=1)

# %%
MER
# Out:
#                                                   MER     MER_PA
# 0               Tamaulipan Mixed Deciduous Thornscrub   5.327991
# 1                        Tamaulipan Savanna Grassland  21.246872
# 2                    Tamaulipan Calcareous Thornscrub   3.808123
# 3                               Tamaulipan Floodplain   1.741697
# 4                                  Tamulipan Ramadero   1.519930
# 5                  Mainly Natural Azonal Mapped Types  15.688131
# 6   Agricultural and other Human-related Mapped Types  30.743329
# 7                Tamaulipan Closed Depression Wetland   0.129112
# 8                        Texas Saline Coastal Prairie   4.613413
# 9           Texas Coast Salt and Brackish Tidal Marsh   2.234754
# 10             Texas Coast Dune and Coastal Grassland   6.264523
# 11      Rio Grande Delta Thorn Woodland and Shrubland   0.199916
# 12                                Texas Coastal Beach   0.014103
# ...

# %%
file1 = "C:\\Users\Bridgett\Desktop\SER.xlsx"
SER= pd.read_excel(file1)

# %%
SER=SER.drop(SER.columns[[0]], axis=1)

# %%
SER
# Out:
#     Veg_ID   SERN     SER_PA  MER
# 0     7004   0.10   3.471420    0
# 1     7005   0.20   1.856571    0
# 2     7103   1.10   0.778934    1
# 3     7104   1.20  12.499605    1
# 4     7105   1.30   2.263467    1
# 5     7107   1.40   5.704866    1
# 6     7204   2.10   2.851292    2
# 7     7205   2.20   0.618409    2
# 8     7207   2.30   0.338422    2
# 9     7402   3.10   0.498958    3
# 10    7403   3.20   0.093016    3
# 11    7404   3.30   0.467672    3
# 12    7405   3.40   0.104047    3
# 13    7406   3.50   0.399084    3
# 14    7602   4.10   0.183984    4
# 15    7604   4.20   0.556489    4
# 16    7605   4.30   0.124246    4
# 17    7606   4.40   0.655173    4
# 18    9000   5.10   0.392101    5
# 19    9007   5.20   0.196841    5
# 20    9104   5.50   0.021109    5
# 21    9106   5.60   0.025796    5
# 22    9124   5.70   0.012898    5
# 23    9187   5.30  13.516917    5
# 24    9304   6.10   0.227684    6
# 25    9307   6.20  22.698033    6
# ...

# %%
#Major Ecoregions Descending
MERA = MER.sort_values(['MER_PA'], ascending=True)

# %%
MERA
# Out:
#                                                   MER     MER_PA
# 17              Tamaulipan Palm Grove Riparian Forest   0.005590
# 12                                Texas Coastal Beach   0.014103
# 14      Southeastern Coastal Plain Interdunal Wetland   0.076421
# 18                             Tamaulipan Saline Lake   0.118624
# 7                Tamaulipan Closed Depression Wetland   0.129112
# 20                       Tamaulipan Caliche Grassland   0.140020
# 11      Rio Grande Delta Thorn Woodland and Shrubland   0.199916
# 16                                   Tamaulipan Lomas   0.588661
# 13  Central and South Texas Coastal Fringe Forest ...   0.926151
# 19                       Tamaulipan Saline Thornscrub   1.370818
# 4                                  Tamulipan Ramadero   1.519930
# 3                               Tamaulipan Floodplain   1.741697
# 9           Texas Coast Salt and Brackish Tidal Marsh   2.234754
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 10))
Label=MERA['MER']
y = np.arange(len(Label))
Area=MERA['MER_PA']
x=[5,10,15,20,25,30]


ax.barh(y, Area, align='center',
        color='kyr', ecolor='black')
ax.set_yticks(y)
ax.set_xticks(x)
ax.set_yticklabels(Label, fontsize=16)
ax.set_xticklabels(x, fontsize=14)
ax.invert_yaxis()
ax.set_xlabel('% Area(Meters)',fontsize=16)
ax.set_title('Major Ecoregions by % Area in the RGV (Meters)',fontsize=24)
plt.show()

# %%
RGVTopER=MERA.tail(5)

# %%
#I want to return rows of SER that have MERA.tail(5) MERN
#This is to get SERN that correspond to the MERN of MERA.tail(5)
SER.loc[SER['MER'] == 0]
# Out:
#    Veg_ID  SERN    SER_PA  MER
# 0    7004   0.1  3.471420    0
# 1    7005   0.2  1.856571    0

# %%
#I need to make SER_PA of 7005 + 7005 = 100
PA_0=SER.loc[SER['MER'] == 0]
PA_0
# Out:
#    Veg_ID  SERN    SER_PA  MER
# 0    7004   0.1  3.471420    0
# 1    7005   0.2  1.856571    0

# %%
MER_TPA_0=np.sum(PA_0['SER_PA'])
MER_TPA_0
# Out:
# 5.327990842308019

# %%
PA_5 = SER.loc[SER['MER'] == 5]
PA_5
# Out:
#     Veg_ID  SERN     SER_PA  MER
# 18    9000  5.10   0.392101    5
# 19    9007  5.20   0.196841    5
# 20    9104  5.50   0.021109    5
# 21    9106  5.60   0.025796    5
# 22    9124  5.70   0.012898    5
# 23    9187  5.30  13.516917    5
# 28    9600  5.40   1.483373    5
# 43    9107  5.80   0.013270    5
# 44    9128  5.90   0.009337    5
# 61    9204  5.11   0.011086    5
# 67    9116  5.01   0.005402    5

# %%
PA_5_A = (SER.loc[SER['MER'] == 5]).sort_values(['SER_PA'], ascending=False)
PA_5_A
# Out:
#     Veg_ID  SERN     SER_PA  MER
# 23    9187  5.30  13.516917    5
# 28    9600  5.40   1.483373    5
# 18    9000  5.10   0.392101    5
# 19    9007  5.20   0.196841    5
# 21    9106  5.60   0.025796    5
# 20    9104  5.50   0.021109    5
# 43    9107  5.80   0.013270    5
# 22    9124  5.70   0.012898    5
# 61    9204  5.11   0.011086    5
# 44    9128  5.90   0.009337    5
# 67    9116  5.01   0.005402    5

# %%
MER_TPA_5=np.sum(PA_5['SER_PA'])
MER_TPA_5
# Out:
# 15.688131134242276

# %%
PA_10 = SER.loc[SER['MER'] == 10]
PA_10
# Out:
#     Veg_ID  SERN    SER_PA  MER
# 38    6307  10.3  6.153547   10
# 49    6200  10.1  0.110249   10
# 50    6306  10.2  0.000727   10

# %%
MER_TPA_10=np.sum(PA_10['SER_PA'])
MER_TPA_10
# Out:
# 6.264523126251958

# %%
PA_1 = SER.loc[SER['MER'] == 1]
PA_1
# Out:
#    Veg_ID  SERN     SER_PA  MER
# 2    7103   1.1   0.778934    1
# 3    7104   1.2  12.499605    1
# 4    7105   1.3   2.263467    1
# 5    7107   1.4   5.704866    1

# %%
MER_TPA_1=np.sum(PA_1['SER_PA'])
MER_TPA_1
# Out:
# 21.246871815418103

# %%
#This is the Percent areas of the Sub ecoregions of Major ER 6
MER6_SERPA=PA_1.SER_PA.tolist()
MER6_SERPA

# %%
PA_6 = SER.loc[SER['MER'] == 6]
PA_6
# Out:
#     Veg_ID  SERN     SER_PA  MER
# 24    9304   6.1   0.227684    6
# 25    9307   6.2  22.698033    6
# 26    9410   6.3   1.407953    6
# 27    9411   6.4   6.344335    6
# 45    9317   6.5   0.065323    6

# %%
MER_TPA_6=np.sum(PA_6['SER_PA'])
MER_TPA_6
# Out:
# 30.743328549872682

# %%
#This is the Percent areas of the Sub ecoregions of Major ER 6
MER6_SERPA=PA_6.SER_PA.tolist()
MER6_SERPA
# Out:
# [0.227684339224381,
#  22.69803300724316,
#  1.407952584870943,
#  6.344335148347521,
#  0.06532347018667209]

# %%
Total_Percent=0
MER6_PA=[] #Major Ecoregion Percent Area

for Area in MER6_SERPA:
    Percent=(Area/MER_TPA_6)*100
    print(Percent)
    MER6_PA.append(Percent)
    Total_Percent=Total_Percent+Percent
    
print(Total_Percent)
# Out:
# 0.7405975538888873
# 73.83075964081696
# 4.579701194641053
# 20.6364614620553
# 0.21248014859777642
# 99.99999999999999

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# Data
r = [0,1,2,3,4]
raw_data = {'greenBars': [20, 1.5, 7, 10, 5], 'orangeBars': [5, 15, 5, 10, 15],'blueBars': [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)
 
# From raw value to percentage
totals = [i+j+k for i,j,k in zip(df['greenBars'], df['orangeBars'], df['blueBars'])]
greenBars = [i / j * 100 for i,j in zip(df['greenBars'], totals)]
orangeBars = [i / j * 100 for i,j in zip(df['orangeBars'], totals)]
blueBars = [i / j * 100 for i,j in zip(df['blueBars'], totals)]
 
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth)
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)
 
# Custom x axis
plt.xticks(r, names)
plt.xlabel("group")
 
# Show graphic
plt.show()

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# Data
r = [0,1,2,3,4]
greenBars = [20, 1.5, 7, 10, 5]
orangeBars = [5, 15, 5, 10, 15]
blueBars = [5, 15, 18, 5, 10]
blackBars = [5, 15, 18, 5, 10]
 
    
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth)
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)
# Create black Bars
plt.bar(r, blackBars, bottom=[i+j+k for i,j,k in zip(greenBars, orangeBars, blueBars)], color='k', edgecolor='white', width=barWidth)



# Custom x axis
plt.xticks(r, names)
plt.xlabel("group")
 
# Show graphic
plt.show()

# %%
RGVTopER
# Out:
#                                                   MER     MER_PA
# 0               Tamaulipan Mixed Deciduous Thornscrub   5.327991
# 10             Texas Coast Dune and Coastal Grassland   6.264523
# 5                  Mainly Natural Azonal Mapped Types  15.688131
# 1                        Tamaulipan Savanna Grassland  21.246872
# 6   Agricultural and other Human-related Mapped Types  30.743329

# %%
MER6_PA
# Out:
# [0.7405975538888873,
#  73.83075964081696,
#  4.579701194641053,
#  20.6364614620553,
#  0.21248014859777642]

# %%
MER6_PAA = MER6_PA.sort_values( ascending=True) 
#Percent Areas of the subregions that make up Major Ecoregion 6 in Ascending order 
MER6_PAA
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-afd78661c1b2> in <module>()
# ----> 1 MER6_PAA = MER6_PA.sort_values( ascending=True)
#       2 #Percent Areas of the subregions that make up Major Ecoregion 6 in Ascending order
#       3 MER6_PAA
#
# AttributeError: 'list' object has no attribute 'sort_values'

# %%
#Now I need to put the areas for the SER_PA into the lists of the bars.




 
# Data
r = [0,1,2,3,4]
greenBars = [20, 1.5, 7, 10, 5]
orangeBars = [5, 15, 5, 10, 15]
blueBars = [5, 15, 18, 5, 10]
blackBars = [5, 15, 18, 5, 10]
 
    
# plot
barWidth = 0.85
names = ('A','B','C','D','E')
# Create green Bars
plt.bar(r, greenBars, color='#b5ffb9', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='#f9bc86', edgecolor='white', width=barWidth)
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)
# Create black Bars
plt.bar(r, blackBars, bottom=[i+j+k for i,j,k in zip(greenBars, orangeBars, blueBars)], color='k', edgecolor='white', width=barWidth)



# Custom x axis
plt.xticks(r, names)
plt.xlabel("group")
 
# Show graphic
plt.show()
