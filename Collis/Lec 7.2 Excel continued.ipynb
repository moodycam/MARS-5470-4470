# %% [markdown]
# # Introduction to Scientific Computing Lecture 7.2
#
# ## File I/O (input/output) continued

# %% [markdown]
# Continue on the tutorial for Pandas and Excel files
#
#
# https://www.dataquest.io/blog/excel-and-pandas/

# %% [markdown]
# ## Exercises:

# %% [markdown]
# Ex.1 From the movies spreadsheet in the above tutorial, make a histogram of all the years movies were made, combining the data in  three sheets. Make two plots, one with bins (bars)  of 10 years width, and one with bins of 20 years width. Label your axes and change the color of the bars. Interpret this data, i.e. describe the change in the number of movies made over time.

# %%
#Import the data
#Combine data in the three sheets

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xarray as xr
import matplotlib as mpl
mpl.rcParams['font.size'] = 14
import pandas as pd

# %%
file = "Desktop/movies.xls"
movies = pd.read_excel(file)

# %%
xlsx = pd.ExcelFile(file)
movies_sheets = []
for sheet in xlsx.sheet_names:
    movies_sheets.append(xlsx.parse(sheet))
movies = pd.concat(movies_sheets)

# %%
movies.shape
# Out:
# (5042, 25)

# %%
#make a histogram of all the years movies were made
movies['Year'].plot(kind="hist",bins=10)
plt.show()

# %%
#make a histogram of all the years movies were made
movies['Year'].plot(kind="hist",bins=10)
plt.show()

# %%
movies.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-39ac96e387ba> in <module>()
# ----> 1 movies.type
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
movies.hist(column=Year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b58c9b926f94> in <module>()
# ----> 1 movies.hist(column=Year)
#
# NameError: name 'Year' is not defined

# %%
movies
# Out:
#                                                   Title    Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                       Over the Hill to the Poorhouse   1920.0
# 2                                       The Big Parade   1925.0
# 3                                           Metropolis   1927.0
# 4                                        Pandora's Box   1929.0
# 5                                  The Broadway Melody   1929.0
# 6                                        Hell's Angels   1930.0
# 7                                   A Farewell to Arms   1932.0
# 8                                          42nd Street   1933.0
# 9                                   She Done Him Wrong   1933.0
# 10                               It Happened One Night   1934.0
# 11                                             Top Hat   1935.0
# 12                                        Modern Times   1936.0
# 13                     The Charge of the Light Brigade   1936.0
# ...

# %%
df=pd.DataFrame(movies['Year'])

# %%
df.hist(figsize=(12,7), bins=10, color='g')
plt.xlabel("Year")
plt.ylabel("Movies Created")
plt.title("Movies created every 10 years")
#ax.set_xlabel("Year")
#ax.set_ylabel("Movies Created")
# Out:
# Text(0.5,1,'Movies created every 10 years')

# %%
df.hist(figsize=(12,7), bins=20, color='g')
plt.xlabel("Year")
plt.ylabel("Movie")
plt.title("Movies")
#ax.set_xlabel("Year")
#ax.set_ylabel("Movies Created")
# Out:
# Text(0.5,1,'Movies')

# %% [markdown]
# #Describe the change in the number of movies made over time.
#
# The creation of movies increased exponentially as time increased.

# %%
#Make two plots, one with bins (bars) of 10 years width
movies['Year'].plot(kind="hist")
plt.xticks(10)
np.linspace
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-fa4474941e66> in <module>()
#       1 #Make two plots, one with bins (bars) of 10 years width
#       2 movies['Year'].plot(kind="hist")
# ----> 3 plt.xticks(10)
#       4 np.linspace
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xticks(*args, **kwargs)
#    1714         labels = ax.get_xticklabels()
#    1715     elif len(args)==1:
# -> 1716         locs = ax.set_xticks(args[0])
#    1717         labels = ax.get_xticklabels()
#    1718     elif len(args)==2:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3234             Default is ``False``.
#    3235         """
# -> 3236         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3237         self.stale = True
#    3238         return ret
#
# ...

# %% [markdown]
# Ex. 2 Make a scatterplot of budget vs. year (x-axis), again combining data from the three sheets. Label your axes. What kind of trend is there in this data, how do budgets change over time? Is the relationship linear?

# %%
year = movies['Year']
budget = movies['Budget']
# We needed two variables for the scatter plot
# This creates the two variables we're looking to analyze

# %%
fig, ax = plt.subplots(figsize = (12,7))
ax.scatter(year, budget)
ax.set_xlabel('Year')
ax.set_ylabel('Budget in 100 Millions')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# There are a few points in the later years that have a positive relationship, however, the beginning of this line has no slope. There is basically no change or slight change over time.

# %% [markdown]
# Ex. 3 Make a scatterplot of budget vs. gross earnings for all of the data. Describe the relationship between these variables, are they correlated?

# %%
#We have to get the budget and gross earnings variables by indexing
budget = movies['Budget']
gross_earnings = movies['Gross Earnings']

# %%
fig, ax = plt.subplots(figsize = (12,7))
ax.scatter(budget, gross_earnings)
ax.set_xlabel('Budget')
ax.set_ylabel('Gross Earnings')
ax.set_title('Budget VS Gross Earnings')
# Out:
# Text(0.5,1,'Budget VS Gross Earnings')

# %% [markdown]
# There does not seem to be a coorelation between these two variables. The outlyer at the end of the scatter plot with a budget of 1.2 million dollars had a much lower Gross Earnings than movies with a lesser budget.

# %% [markdown]
# Ex. 4 What is the lowest IMDB score? Find this using the programming techniques we learned in class

# %%
np.min(movies['IMDB Score'])
# Out:
# 1.6

# %% [markdown]
# Ex. 5 Find the names of all the movies with an IMDB score below 5 and put them in an array or list, with an associated array of their IMDB scores. Write these titles and scores to a text file with the appropriate header information

# %%
IMDB = movies['IMDB Score']
sub_movies = movies[IMDB < 5]

# %%
bad_movies = np.array([sub_movies['Title'], sub_movies['IMDB Score']])
bad_movies.T
# Out:
# array([['Over the Hill to the Poorhouse\xa0', 4.8],
#        ["The Brain That Wouldn't Die\xa0", 4.1],
#        ['The Stewardesses\xa0', 4.0],
#        ['Exorcist II: The Heretic\xa0', 3.7],
#        ['Alien Zone\xa0', 4.1],
#        ['Meteor\xa0', 4.9],
#        ["Can't Stop the Music\xa0", 4.5],
#        ['Galaxina\xa0', 3.4],
#        ['Raise the Titanic\xa0', 4.7],
#        ['Graduation Day\xa0', 4.5],
#        ['Heartbeeps\xa0', 4.2],
#        ['Inchon\xa0', 2.7],
#        ['Butterfly\xa0', 4.5],
#        ['Halloween III: Season of the Witch\xa0', 4.6],
#        ['Megaforce\xa0', 3.5],
#        ["Losin' It\xa0", 4.8],
#        ['Superman III\xa0', 4.9],
#        ['The Wicked Lady\xa0', 4.0],
#        ['Sheena\xa0', 4.8],
#        ['Def-Con 4\xa0', 4.3],
#        ['Friday the 13th: A New Beginning\xa0', 4.7],
#        ['Howard the Duck\xa0', 4.6],
#        ['Shanghai Surprise\xa0', 3.0],
#        ['American Ninja 2: The Confrontation\xa0', 4.7],
#        ['Ishtar\xa0', 4.2],
# ...

# %%
bad_movies2 = pd.DataFrame(bad_movies.T, columns = ('Title', 'IMDB Score'))
bad_movies2.to_csv('Desktop/Bad_movies.csv', header='Movies with IMDB Scores under 5', index = False)
