# %%
#Variables

#t = np.arange(2005., 2055., 1.)
# t is an arrange of time from 2005 to 2054


#x1 = np.linspace(Excel_raw['Current Water Depth'][0], Excel_raw['Water Level 2054'][0], num=50)
#x1: is an arrange with the water depth level at each year for pool 1 between 2005 and 2054

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xarray as xr
import pandas as pd

#Importing the required libraries to run this code
# Out:
# C:\Users\gak904\AppData\Local\Continuum\anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\gak904\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
file = 'C:\\Users\gak904\Documents\Python_Final_Project_\Excel_raw.xlsx'
Excel_raw = pd.read_excel(file)

# %%
Excel_raw.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Current Water Depth  Year 2055  Year 2005
# 0                             51.2                 99.1       2055       2005
# 1                             30.5                157.8       2055       2005
# 2                             34.3                 70.5       2055       2005

# %%
#Pool: Code for each individual resaca
#Data point: this one was created to have a numerical order of the pools
#Average Sediment Thickness 1976: Average of the measurements of sediment taken in 1976
#Average Sediment Thickness 2004: Average of the measurements of sediment taken in 2004
#Current water depth: Water level in each resaca taken in 2004

# %%
Excel_raw["Sedimentation Rate"] = (Excel_raw["Average Sediment Thickness 2004"] - Excel_raw["Average Sediment Thickness 1976"]) / 28 
#With this line, I created a new column in the file with the sedimentation rate, this is calculated by substracting avg thicknes of 2004 minus avg thickness 1976 and divided by 28 years.

# %%
Excel_raw.head(3)
#In the next table we can see the new column that was added.
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Current Water Depth  Year 2055  Year 2005  \
# 0                             51.2                 99.1       2055       2005
# 1                             30.5                157.8       2055       2005
# 2                             34.3                 70.5       2055       2005
#
#    Sedimentation Rate
# 0            0.260714
# 1            0.267857
# 2            0.225000

# %%
t = np.arange(2005., 2055., 1.)
# t is an arrange of time from 2005 to 2054

# %%
t
# Out:
# array([2005., 2006., 2007., 2008., 2009., 2010., 2011., 2012., 2013.,
#        2014., 2015., 2016., 2017., 2018., 2019., 2020., 2021., 2022.,
#        2023., 2024., 2025., 2026., 2027., 2028., 2029., 2030., 2031.,
#        2032., 2033., 2034., 2035., 2036., 2037., 2038., 2039., 2040.,
#        2041., 2042., 2043., 2044., 2045., 2046., 2047., 2048., 2049.,
#        2050., 2051., 2052., 2053., 2054.])

# %%
Excel_raw['Water Level 2054'] = Excel_raw['Current Water Depth'] - (Excel_raw['Sedimentation Rate'] * 50)

# %%
Excel_raw.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Current Water Depth  Year 2055  Year 2005  \
# 0                             51.2                 99.1       2055       2005
# 1                             30.5                157.8       2055       2005
# 2                             34.3                 70.5       2055       2005
#
#    Sedimentation Rate  Water Level 2054
# 0            0.260714         86.064286
# 1            0.267857        144.407143
# 2            0.225000         59.250000

# %%
xx_tr = np.linspace(Excel_raw['Current Water Depth'][0:12], Excel_raw['Water Level 2054'][0:12], num=50)
#this one creates an array for Town Resaca pools, starting point 'Current water depth' ends at 'Water level at year 2054' and makes 50 points.

# %%
tt_tr = np.linspace(Excel_raw['Year 2005'][0:12], Excel_raw['Year 2055'][0:12], num=50)
#this array is for the years between 2005 and 2055.

# %%
xx_rg = np.linspace(Excel_raw['Current Water Depth'][13:49], Excel_raw['Water Level 2054'][13:49], num=50)
#this one creates an array for Resaca de la Guerra pools, starting point 'Current water depth' ends at 'Water level at year 2054' and makes 50 points.

# %%
tt_rg = np.linspace(Excel_raw['Year 2005'][13:49], Excel_raw['Year 2055'][13:49], num=50)
#this array is for the years between 2005 and 2055.

# %%
fig, a1 = plt.subplots(figsize=(12,12))
fig, a2 = plt.subplots(figsize=(12,12))

TR_list = ["TR02", "TR03", "TR04", "TR05", "TR06", "TR07", "TR08", "TR09", "TR10", "TR11", "TR13", "TR14"]
RG_list = ["RG16", "RG17", "RG18", "RG19", "RG20", "RG21", "RG22", "RG23", "RG24", "RG25", "RG26", "RG27", "RG28", "RG29", "RG30", "RG31", "RG32", "RG33", "RG34", "RG35", "RG36", "RG37", "RG38", "RG39", "RG40", "RG41", "RG42", "RG43", "RG44", "RG45", "RG46", "RG51", "RG52", "RG53", "RG54", "RG55", "RG56", "RG57"]

fig.suptitle('Projected Water Depth in Resacas in Browsnville') 



a1.plot(tt_tr, xx_tr)
a1.set_xlim([2005, 2055])
a1.set_ylim([0, 190])
a1.set_title("Town Resaca")
leg = a1.legend(TR_list);
a1.set_xlabel('Time')
a1.set_ylabel('Centimeters')



a2.plot(tt_rg, xx_rg)
a2.set_xlim([2005, 2055])
a2.set_ylim([0, 190])
a2.set_title("Resaca de la Guerra")
leg = a2.legend(RG_list, loc='upper right');
a2.set_xlabel('Time')
a2.set_ylabel('Centimeters')


a1.title.set_text('Town Resaca')
a2.title.set_text('Resaca de la Guerra')

plt.savefig('plots.png', dpi=450)

#figure out for each resaca which year they will reach 0

# %%
Excel_raw.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Current Water Depth  Year 2055  Year 2005  \
# 0                             51.2                 99.1       2055       2005
# 1                             30.5                157.8       2055       2005
# 2                             34.3                 70.5       2055       2005
#
#    Sedimentation Rate  Water Level 2054
# 0            0.260714         86.064286
# 1            0.267857        144.407143
# 2            0.225000         59.250000

# %%
#dry year

# %%
from collections import Counter

# %%
y = [Excel_raw['Current Water Depth']]

# %%
Excel_raw['Dry year'] = Excel_raw['Current Water Depth'] - Excel_raw['Sedimentation Rate'] 

while Excel_raw['Dry year'] >= 0:
    
    Excel_raw['Dry year'] = Excel_raw['Current Water Depth'] - Excel_raw['Sedimentation Rate'] 
    
    if Excel_raw['Dry year'] == 0:
        
        break
        
        print (Excel_raw['Dry year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-fb1b26f83e7b> in <module>
#       1 Excel_raw['Dry year'] = Excel_raw['Current Water Depth'] - Excel_raw['Sedimentation Rate']
#       2
# ----> 3 while Excel_raw['Dry year'] >= 0:
#       4
#       5     Excel_raw['Dry year'] = Excel_raw['Current Water Depth'] - Excel_raw['Sedimentation Rate']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
d0 = np.array(Excel_raw['Current Water Depth'])
rate = np.array(Excel_raw['Sedimentation Rate'])

# %%
d0 = np.array(Excel_raw['Current Water Depth']) 

# loop over each resaca
for resaca in d0: 
    # calculate the dpeth after one year
    Excel_raw['Zero'] = Excel_raw['Current Water Depth'] - Excel_raw['Sedimentation Rate']
    if Excel_raw['Zero'].all == 0:
        break
  



           
#if(np.array(Excel_raw['Zero']) == 0):       
#break

# %%
Excel_raw
# Out:
#     Pool  Data Point  Average Sediment Thickness 1976  \
# 0   TR02           1                             43.9
# 1   TR03           2                             23.0
# 2   TR04           3                             28.0
# 3   TR05           4                             32.3
# 4   TR06           5                             18.0
# 5   TR07           6                             33.5
# 6   TR08           7                             22.9
# 7   TR09           8                             20.4
# 8   TR10           9                             68.3
# 9   TR11          10                             60.0
# 10  TR13          11                             41.1
# 11  TR14          12                             51.2
# 12  RG16          13                             19.8
# 13  RG17          14                             18.6
# 14  RG18          15                             20.1
# 15  RG19          16                             18.9
# ...

# %%
for x in i.all:
    Excel_raw['Dry Year'] = i.all - (j.all*n)
    #n + 5
    #if any(Excel_raw['Dry Year']) == 0:
        #Excel_raw['Years to be dry'] = n
        #break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e61659843b86> in <module>
#       1
# ----> 2 for x in i.all:
#       3     Excel_raw['Dry Year'] = i.all - (j.all*n)
#       4     #n + 5
#       5     #if any(Excel_raw['Dry Year']) == 0:
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
Excel_raw.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Current Water Depth  Year 2055  Year 2005  \
# 0                             51.2                 99.1       2055       2005
# 1                             30.5                157.8       2055       2005
# 2                             34.3                 70.5       2055       2005
#
#    Sedimentation Rate  Water Level 2054    Dry year  One year    Dry Year  \
# 0            0.260714         86.064286   98.839286       0.0   96.492857
# 1            0.267857        144.407143  157.532143       0.0  155.121429
# 2            0.225000         59.250000   70.275000       0.0   68.250000
#
#    Years to be dry
# 0                2
# 1                2
# 2                2

# %%
while i.all > 0:
    Excel_raw['Dry Year'].all = i.all - (j.all*n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-336e8a270924> in <module>
# ----> 1 while i.all > 0:
#       2     Excel_raw['Dry Year'].all = i.all - (j.all*n)
#       3
#
# TypeError: '>' not supported between instances of 'builtin_function_or_method' and 'int'

# %%
file = 'C:\\Users\gak904\Documents\Python_Final_Project_\Enteros.xlsx'
Enteros = pd.read_excel(file)

# %%
Enteros.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Actual Water Level  Rate
# 0                             51.2                  99     1
# 1                             30.5                 158     2
# 2                             34.3                  71     3

# %%
z = np.array(Enteros['Actual Water Level'])
x = np.array(Enteros['Rate'])

# %%
n=1
for x in Enteros['Actual Water Level']:
    Enteros['Cero'] = Enteros['Actual Water Level'] - (Enteros['Rate'] * n)
    n + 1
    if any(Enteros['Cero']) == 0:
        break

# %%
Enteros['Zero'] = Enteros['Actual Water Level'] - Enteros['Rate']

while Enteros['Zero'] > 0:
    Enteros['Zero'] = Enteros['Actual Water Level'] - Enteros['Rate']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-598b1f83c9b3> in <module>
#       1 Enteros['Zero'] = Enteros['Actual Water Level'] - Enteros['Rate']
#       2
# ----> 3 while Enteros['Zero'] > 0:
#       4     Enteros['Zero'] = Enteros['Actual Water Level'] - Enteros['Rate']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Enteros['Zero'] = Enteros['Actual Water Level'] - Enteros['Rate']

# %%
Enteros['Zero']
# Out:
# 0      98
# 1     156
# 2      68
# 3      74
# 4      63
# 5      93
# 6      94
# 7      72
# 8      47
# 9      45
# 10     41
# 11     59
# 12     30
# 13     34
# 14     29
# 15     38
# 16     55
# 17     61
# 18     82
# 19     67
# 20     62
# 21     65
# 22     81
# 23     65
# 24     94
# 25    111
# 26    118
# 27    128
# 28    170
# 29     93
# 30     62
# 31    106
# 32     14
# 33     81
# 34    100
# 35    141
# 36     87
# 37    101
# 38    115
# 39    149
# 40    135
# 41    109
# 42    102
# 43     95
# 44    117
# 45     93
# 46     69
# 47     89
# 48     78
# 49     77
# Name: Zero, dtype: int64

# %%
Enteros
# Out:
#     Pool  Data Point  Average Sediment Thickness 1976  \
# 0   TR02           1                             43.9
# 1   TR03           2                             23.0
# 2   TR04           3                             28.0
# 3   TR05           4                             32.3
# 4   TR06           5                             18.0
# 5   TR07           6                             33.5
# 6   TR08           7                             22.9
# 7   TR09           8                             20.4
# 8   TR10           9                             68.3
# 9   TR11          10                             60.0
# 10  TR13          11                             41.1
# 11  TR14          12                             51.2
# 12  RG16          13                             19.8
# 13  RG17          14                             18.6
# 14  RG18          15                             20.1
# 15  RG19          16                             18.9
# ...

# %%
Enteros.head(3)
# Out:
#    Pool  Data Point  Average Sediment Thickness 1976  \
# 0  TR02           1                             43.9
# 1  TR03           2                             23.0
# 2  TR04           3                             28.0
#
#    Average Sediment Thickness 2004  Actual Water Level  Rate  Zero
# 0                             51.2                  99     1    98
# 1                             30.5                 158     2   156
# 2                             34.3                  71     3    68

# %%
Enteros['Years to become dry'] = (Enteros['Actual Water Level'] / Enteros['Rate']) + 2004

# %%
Enteros
# Out:
#     Pool  Data Point  Average Sediment Thickness 1976  \
# 0   TR02           1                             43.9
# 1   TR03           2                             23.0
# 2   TR04           3                             28.0
# 3   TR05           4                             32.3
# 4   TR06           5                             18.0
# 5   TR07           6                             33.5
# 6   TR08           7                             22.9
# 7   TR09           8                             20.4
# 8   TR10           9                             68.3
# 9   TR11          10                             60.0
# 10  TR13          11                             41.1
# 11  TR14          12                             51.2
# 12  RG16          13                             19.8
# 13  RG17          14                             18.6
# 14  RG18          15                             20.1
# 15  RG19          16                             18.9
# ...
