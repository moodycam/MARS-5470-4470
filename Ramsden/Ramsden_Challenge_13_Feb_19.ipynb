# %%
print('hola')
# Out:
# hola

# %%
x =('hola')

# %%
x
# Out:
# 'hola'

# %%
y=("hola")

# %%
import numpy as np

# %%
import numpy as np

# matplotlib imports
import matplotlib.pyplot as plt
# needed for Jupyter notebooks.
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(9,9), nrows=3, ncols=4)

ax[0,0].set_title('January', fontsize=18)
ax[0,1].set_title('February', fontsize=18)
ax[0,2].set_title('March', fontsize=18)
ax[0,3].set_title('April', fontsize=18)
ax[1,0].set_title('May', fontsize=18)
ax[1,1].set_title('June', fontsize=18)
ax[1,2].set_title('July', fontsize=18)
ax[1,3].set_title('August', fontsize=18)
ax[2,0].set_title('September', fontsize=18)
ax[2,1].set_title('October', fontsize=18)
ax[2,2].set_title('November', fontsize=18)
ax[2,3].set_title('December', fontsize=18)
# Out:
# Text(0.5, 1.0, 'December')

# %%
import xarray as xr

# %%
data = xr.open_dataset('C:\\Users\srv_veralab\Downloads\CESM.003.SST.1980.nc')
lat = np.array(data.lat)
lon = np.array(data.lon)
sst = np.array(data.SST)

# %%
data.shape
# Out:
# (12, 180, 360)

# %%
meandata = np.mean(data, axis=0)

# %%
fig, myax = plt.subplots(figsize=(9,9), nrows=3, ncols=4,sharex=True,
                       sharey=True)
fig.colorbar(ax = myax)

myax[0,0].set_title('January', fontsize=18)
myax[0,1].set_title('February', fontsize=18)
myax[0,2].set_title('March', fontsize=18)
myax[0,3].set_title('April', fontsize=18)
myax[1,0].set_title('May', fontsize=18)
myax[1,1].set_title('June', fontsize=18)
myax[1,2].set_title('July', fontsize=18)
myax[1,3].set_title('August', fontsize=18)
myax[2,0].set_title('September', fontsize=18)
myax[2,1].set_title('October', fontsize=18)
myax[2,2].set_title('November', fontsize=18)
myax[2,3].set_title('December', fontsize=18)

myax[0,0].pcolormesh(lon, lat, sst[0])
myax[0,1].pcolormesh(lon, lat, sst[1])
myax[0,2].pcolormesh(lon, lat, sst[2])
myax[0,3].pcolormesh(lon, lat, sst[3])
myax[1,0].pcolormesh(lon, lat, sst[4])
myax[1,1].pcolormesh(lon, lat, sst[5])
myax[1,2].pcolormesh(lon, lat, sst[6])
myax[1,3].pcolormesh(lon, lat, sst[7])
myax[2,0].pcolormesh(lon, lat, sst[8])
myax[2,1].pcolormesh(lon, lat, sst[9])
myax[2,2].pcolormesh(lon, lat, sst[10])
myax[2,3].pcolormesh(lon, lat, sst[11])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-2e8c11c91e18> in <module>()
#       1 fig, myax = plt.subplots(figsize=(9,9), nrows=3, ncols=4,sharex=True,
#       2                        sharey=True)
# ----> 3 fig.colorbar(ax = myax)
#       4
#       5 myax[0,0].set_title('January', fontsize=18)
#
# TypeError: colorbar() missing 1 required positional argument: 'mappable'

# %%
fig, myax = plt.subplots(figsize=(9,9), nrows=3, ncols=4,sharex=True,
                       sharey=True)
im = myax[0,0].pcolormesh(lon,lat,data[0,:,:])
fig.colorbar(im, ax = myax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\xarray\core\dataset.py in _copy_listed(self, names)
#     869             try:
# --> 870                 variables[name] = self._variables[name]
#     871             except KeyError:
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-003f5713d7db> in <module>()
#       1 fig, myax = plt.subplots(figsize=(9,9), nrows=3, ncols=4,sharex=True,
#       2                        sharey=True)
# ----> 3 im = myax[0,0].pcolormesh(lon,lat,data[0,:,:])
#       4 fig.colorbar(im, ax = myax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\xarray\core\dataset.py in __getitem__(self, key)
#     961             return self._construct_dataarray(key)
# ...

# %%
#Check pictures for for loop
#months can be the same with for loop creating a list
