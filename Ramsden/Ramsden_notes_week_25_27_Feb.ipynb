# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xarray as xr

# %%
# if I want to change all of my plots:
import matplotlib as mpl
mpl.rcParams['font.size'] = 14
# note this method changes tick mark font sizes as well

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
file = 'C:\\Users\srv_veralab\Downloads\movies.xls'
movies = pd.read_excel(file)

# %%
movies
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# 5                                  The Broadway Melody   1929
# 6                                        Hell's Angels   1930
# 7                                   A Farewell to Arms   1932
# 8                                          42nd Street   1933
# 9                                   She Done Him Wrong   1933
# 10                               It Happened One Night   1934
# 11                                             Top Hat   1935
# 12                                        Modern Times   1936
# 13                     The Charge of the Light Brigade   1936
# ...

# %%
movies.shape
# Out:
# (1338, 25)

# %%
movies.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...

# %%
movies_sheet1 = pd.read_excel(file, sheet_name=0, index_col=0)
movies_sheet1.head()
# Out:
#                                                    Year               Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
#
#                                                   Content Rating  Duration  \
# ...

# %%
movies_sheet2 = pd.read_excel(file, sheet_name=1, index_col=0)
movies_sheet2.head()
# Out:
#                         Year                   Genres Language Country  \
# Title
# 102 Dalmatians          2000  Adventure|Comedy|Family  English     USA
# 28 Days                 2000             Comedy|Drama  English     USA
# 3 Strikes               2000                   Comedy  English     USA
# Aberdeen                2000                    Drama  English      UK
# All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#                        Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 102 Dalmatians                      G     100.0          1.85  85000000.0
# 28 Days                         PG-13     103.0          1.37  43000000.0
# 3 Strikes                           R      82.0          1.85   6000000.0
# Aberdeen                          NaN     106.0          1.85   6500000.0
# All the Pretty Horses           PG-13     220.0          2.35  57000000.0
#
#                         Gross Earnings            Director  ...  \
# ...

# %%
movies_sheet3 = pd.read_excel(file, sheet_name=2, index_col=0)
movies_sheet3.head()
# Out:
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                                                   Genres  \
# Title
# 127 Hours                             Adventure|Biography|Drama|Thriller
# 3 Backyards                                                        Drama
# 3                                                   Comedy|Drama|Romance
# 8: The Mormon Proposition                                    Documentary
# A Turtle's Tale: Sammy's Adventures           Adventure|Animation|Family
#
#                                      Language  Country Content Rating  \
# Title
# 127 Hours                             English      USA              R
# 3 Backyards                           English      USA              R
# ...

# %%
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])

# %%
movies.shape
# Out:
# (5042, 24)

# %%
movies.tail()
# Out:
#                                       Year  \
# Title
# War & Peace                            NaN
# Wings                                  NaN
# Wolf Creek                             NaN
# Wuthering Heights                      NaN
# Yu-Gi-Oh! Duel Monsters                NaN
#
#                                                                          Genres  \
# Title
# War & Peace                                           Drama|History|Romance|War
# Wings                                                              Comedy|Drama
# Wolf Creek                                                Drama|Horror|Thriller
# Wuthering Heights                                                 Drama|Romance
# Yu-Gi-Oh! Duel Monsters               Action|Adventure|Animation|Family|Fantasy
#
#                                       Language    Country Content Rating  \
# Title
# War & Peace                            English         UK          TV-14
# ...

# %%
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)

# %%
sorted_by_gross["Gross Earnings"].head(10)
# Out:
# Title
# Avatar                                        760505847.0
# Titanic                                       658672302.0
# Jurassic World                                652177271.0
# The Avengers                                  623279547.0
# The Avengers                                  623279547.0
# The Dark Knight                               533316061.0
# Star Wars: Episode I - The Phantom Menace     474544677.0
# Star Wars: Episode IV - A New Hope            460935665.0
# Avengers: Age of Ultron                       458991599.0
# The Dark Knight Rises                         448130642.0
# Name: Gross Earnings, dtype: float64

# %%
sorted_by_gross['Gross Earnings'].head(10).plot(kind="barh")
plt.show()

# %%
movies['IMDB Score'].plot(kind="hist")
plt.show()

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  4935.000000  5028.000000   4714.000000  4.551000e+03    4.159000e+03
# mean   2002.470517   107.201074      2.220403  3.975262e+07    4.846841e+07
# std      12.474599    25.197441      1.385113  2.061149e+08    6.845299e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    1.620000e+02
# 25%    1999.000000    93.000000      1.850000  6.000000e+06    5.340988e+06
# 50%    2005.000000   103.000000      2.350000  2.000000e+07    2.551750e+07
# 75%    2011.000000   118.000000      2.350000  4.500000e+07    6.230944e+07
# max    2016.000000   511.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                4938.000000               5035.000000
# mean                  686.621709               6561.323932
# std                  2813.602405              15021.977635
# ...

# %%
movies["Gross Earnings"].mean()
# Out:
# 48468407.52680933

# %%
movies_subset_columns = pd.read_excel(file, parse_cols=6)
movies_subset_columns.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:527: FutureWarning: Passing in an integer for `usecols` has been deprecated. Please pass in a list of int from 0 to `usecols` inclusive instead.
#   usecols = _maybe_convert_usecols(usecols)
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration
# 0    Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
sorted_movies = movies[['Net Earnings']].sort_values(['Net Earnings'], ascending=[False])
sorted_movies.head(10)['Net Earnings'].plot.barh()
plt.show()

# %%
movies_subset = movies[['Year', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                      Year  Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0             NaN
# Over the Hill to the Poorhouse                     1920.0       3000000.0
# The Big Parade                                     1925.0             NaN
# Metropolis                                         1927.0         26435.0
# Pandora's Box                                      1929.0          9950.0

# %%
earnings_by_year = movies_subset.pivot_table(index=['Year'])
earnings_by_year.head()
# Out:
#         Gross Earnings
# Year
# 1920.0       3000000.0
# 1927.0         26435.0
# 1929.0       1408975.0
# 1933.0       2300000.0
# 1935.0       3000000.0

# %%
earnings_by_year.plot()
plt.show()

# %%
movies_subset = movies[['Country', 'Language', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                    Country Language  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       USA      NaN
# Over the Hill to the Poorhouse                         USA      NaN
# The Big Parade                                         USA      NaN
# Metropolis                                         Germany   German
# Pandora's Box                                      Germany   German
#
#                                                    Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0

# %%
earnings_by_co_lang = movies_subset.pivot_table(index=['Country', 'Language'])
earnings_by_co_lang.head()
# Out:
#                         Gross Earnings
# Country     Language
# Afghanistan Dari          1.127331e+06
# Argentina   Spanish       7.230936e+06
# Aruba       English       1.007614e+07
# Australia   Aboriginal    6.165429e+06
#             Dzongkha      5.052950e+05

# %%
earnings_by_co_lang.head(20).plot(kind='bar', figsize=(20,8))
plt.show()

# %%
movies
# Out:
#                                                      Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0
# The Broadway Melody                                1929.0
# Hell's Angels                                      1930.0
# A Farewell to Arms                                 1932.0
# 42nd Street                                        1933.0
# She Done Him Wrong                                 1933.0
# It Happened One Night                              1934.0
# Top Hat                                            1935.0
# Modern Times                                       1936.0
# The Charge of the Light Brigade                    1936.0
# Snow White and the Seven Dwarfs                    1937.0
# ...

# %%
movies_subset = movies[['Year']]
movies_subset.head()
# Out:
#                                                      Year
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0

# %%
movies_subset['Year'].plot(kind="hist")
df = movies_subset.hist(bins=[1910,1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2020])
df = movies_subset.hist(bins=[1910,1930,1950,1970,1990,2010])

# %% [markdown]
# # Ex. 2 Make a scatterplot of budget vs. year (x-axis), again combining data from the three sheets. Label your axes. What kind of trend is there in this data, how do budgets change over time? Is the relationship linear?

# %%
movies
# Out:
#                                                      Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0
# Over the Hill to the Poorhouse                     1920.0
# The Big Parade                                     1925.0
# Metropolis                                         1927.0
# Pandora's Box                                      1929.0
# The Broadway Melody                                1929.0
# Hell's Angels                                      1930.0
# A Farewell to Arms                                 1932.0
# 42nd Street                                        1933.0
# She Done Him Wrong                                 1933.0
# It Happened One Night                              1934.0
# Top Hat                                            1935.0
# Modern Times                                       1936.0
# The Charge of the Light Brigade                    1936.0
# Snow White and the Seven Dwarfs                    1937.0
# ...

# %%
movies_subset2 = movies[['Year','Budget']]
movies_subset2.head()
# Out:
#                                                      Year     Budget
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0   385907.0
# Over the Hill to the Poorhouse                     1920.0   100000.0
# The Big Parade                                     1925.0   245000.0
# Metropolis                                         1927.0  6000000.0
# Pandora's Box                                      1929.0        NaN

# %%
x = movies_subset2['Year']

# %%
y = movies_subset2['Budget']

# %%
plt.scatter(x, y, marker='.')
plt.xlabel('Year')
plt.ylabel('Budget');

# %%
plt.scatter(x, y, marker='.')
plt.xlabel('Year')
plt.ylabel('Budget')
plt.ylim([0,100000000]);

# %% [markdown]
# # Ex. 3 Make a scatterplot of budget vs. gross earnings for all of the data. Describe the relationship between these variables, are they correlated?

# %%
movies_subset3 = movies[['Budget','Gross Earnings']]
movies_subset3.head()
# Out:
#                                                       Budget  Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages    385907.0             NaN
# Over the Hill to the Poorhouse                      100000.0       3000000.0
# The Big Parade                                      245000.0             NaN
# Metropolis                                         6000000.0         26435.0
# Pandora's Box                                            NaN          9950.0

# %%
a = movies_subset3['Budget']

# %%
b = movies_subset3['Gross Earnings']

# %%
plt.scatter(a, b, marker='o')
plt.xlabel('Budget')
plt.ylabel('Gross Earnings');

# %% [markdown]
# Ex. 4 What is the lowest IMDB score? Find this using the programming techniques we learned in class

# %%
sorted_by_imdb = movies.sort_values(['IMDB Score'], ascending=True)

# %%
sorted_by_imdb["IMDB Score"].head(1)
# Out:
# Title
# Justin Bieber: Never Say Never     1.6
# Name: IMDB Score, dtype: float64

# %% [markdown]
# Ex. 5 Find the names of all the movies with an IMDB score below 5 and put them in an array or list, with an associated array of their IMDB scores. Write these titles and scores to a text file with the appropriate header information

# %%
movies_subset5 = movies[['IMDB Score']]

# %%
my_list = [movies_subset5]

# %%
movies_subset5.shape
# Out:
# (5042, 1)

# %%
my_list = [movies_subset5 <= 5.0]
